# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %% [markdown]
# # Limitation of read_html():

# %% [markdown]
# It will always try to scrap a tabular format of the data
#
# if the data is not available in tabular format it is not able to scratch

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]

# this data is available at 0th index of list
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])

# data type of df[0] is dataframe means inside a list at 0th index dataset
# is available that is dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# storing data inside df1 variable

# %%
df1.columns
# it shows the list of all columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# it give you sample data
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.dtypes

# it shows the data type of all the column
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]

# it show column whatever you want
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA.csv',index = False)

#if we want show all the hidden data for that we save this data in csv format
#"NBA.csv" is the name of that file and if we dont want index, make it False

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1004-C407
#
#  Directory of C:\Users\vijay\OneDrive\Desktop\Data_Science\Python_Classes
#
# 05/04/2022  11:31 AM    <DIR>          .
# 05/04/2022  11:31 AM    <DIR>          ..
# 05/04/2022  10:43 AM    <DIR>          .ipynb_checkpoints
# 02/16/2022  12:24 PM    <DIR>          __pycache__
# 04/13/2022  03:03 PM            20,039 13th_Feb_mogngodb.ipynb
# 02/02/2022  02:48 PM            22,955 15th_Jan.ipynb
# 02/01/2022  10:16 PM            15,272 15th_jan_Logging.ipynb
# 01/24/2022  01:26 PM            53,959 19Th_Dec_Fun_Practice_Prob.ipynb
# 04/19/2022  02:16 PM            48,584 20th_Feb_SQL_Lite.ipynb
# 02/07/2022  08:38 PM            13,415 22_Jan_22.ipynb
# 02/16/2022  12:22 PM            15,574 23_jan_01.ipynb
# 02/16/2022  12:39 PM             2,640 23_jan_02.ipynb
# 02/23/2022  12:20 PM            17,068 29_jan.ipynb
# 03/20/2022  11:22 AM            69,008 5th_feb_SQL.ipynb
# 03/24/2022  07:03 PM           556,171 6th_Feb_SQL.ipynb
# 01/13/2022  12:46 PM            30,008 8th_Jan_22.ipynb
# 01/23/2022  07:49 PM            16,792 9th_Jan.ipynb
# 03/24/2022  07:38 PM            51,867 car.data
# 03/08/2022  12:17 PM            11,903 glass (1).data
# 01/24/2022  12:24 PM             5,060 google.txt
# 04/15/2022  01:49 PM             8,192 ineuron.db
# 04/18/2022  01:00 PM             5,176 Join_Tale_Operation_SQLite.ipynb
# 04/18/2022  11:26 AM            12,288 joindb.db
# 04/18/2022  11:37 AM             8,720 joindb.db-journal
# 04/18/2022  12:54 PM             1,321 Joint_Table_Operating_SQLite.ipynb
# 04/18/2022  12:22 PM            12,288 jointable.db
# 04/18/2022  12:39 PM            12,824 jointable.db-journal
# 04/29/2022  11:52 AM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 04/29/2022  11:52 AM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 04/29/2022  11:52 AM            95,503 LUSID Excel - Manage instruments with economic definitions.xlsx
# 04/29/2022  11:52 AM            84,319 LUSID Excel - Manage Orders.xlsx
# 04/29/2022  11:52 AM           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 04/29/2022  11:52 AM           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 04/29/2022  11:52 AM           136,632 LUSID Excel - Setting up your market data.xlsx
# 04/03/2022  08:33 PM            57,313 mongodb class 1.ipynb
# 02/04/2022  08:02 PM               223 my_module.py
# 02/04/2022  08:01 PM               219 my_module.py.bak
# 02/16/2022  12:23 PM               655 mydict.py
# 02/16/2022  12:21 PM                 0 mydict.py.bak
# 05/04/2022  11:32 AM            81,552 NBA.csv
# 04/29/2022  12:16 PM           177,800 Pandas.ipynb
# 05/04/2022  11:31 AM            43,851 Pandas_02.ipynb
# 04/15/2022  02:13 PM                 0 person.db
# 04/15/2022  02:16 PM             8,192 pesron.db
# 04/18/2022  11:10 AM             4,616 pesron.db-journal
# 04/28/2022  08:43 PM               173 sample_test.csv
# 04/28/2022  01:18 PM               173 sample_test.csv.bak
# 04/28/2022  08:38 PM               163 sample_test_01.csv
# 04/28/2022  08:55 PM            19,128 services.csv
# 03/08/2022  12:22 PM            80,353 SQL basic .ipynb
# 03/24/2022  06:45 PM           358,223 sql day 2 .ipynb
# 04/28/2022  07:14 PM            14,618 taxonomy.csv
# 02/02/2022  02:46 PM             4,053 test.log
# 01/26/2022  11:50 AM                16 test.txt
# 02/04/2022  01:56 PM               187 test1.py
# 02/04/2022  01:53 PM               187 test1.py.bak
# 02/01/2022  07:37 PM                23 test1.txt
# 02/01/2022  09:57 PM                 0 test2.log
# 02/04/2022  01:48 PM                 0 test2.py
# 01/24/2022  10:39 AM                20 test2.txt
# 01/24/2022  10:39 AM                23 test3.txt
# 02/01/2022  07:37 PM                 0 test43.txt
# 01/23/2022  08:24 PM                85 test5
# 01/24/2022  10:39 AM                65 test5.txt
# 03/28/2022  12:47 PM            64,527 Untitled.ipynb
#               61 File(s)      2,888,843 bytes
#                4 Dir(s)  88,676,909,056 bytes free

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)

# there are 3 tables
# Out:
# 3

# %%
l[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# 1    0  0  0   0   0
# 2    -  -  -   -   -
# 3    0  0  0  14   1
# 4    -  -  -   -   -
# ..  .. .. ..  ..  ..
# 92   0  0  0   0   0
# 93   0  0  3   4   3
# 94   0  4  1  32  20
# 95   0  0  0   0   0
# 96   0  8  1  77  74
#
# [97 rows x 15 columns]

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
# 2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...

# %%
l[0].to_csv('cricket.csv',index = False)

# converting table 01 data into csv format.

# %%
 d = """{"name": "vijay",
      "mail_id": "vijay@gmail.com",
      "tech":["ML", "DL", "cv"],
      "plateform": ["technueron","kidneuron","ineuron"]
      }"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'name': 'vijay',
#  'mail_id': 'vijay@gmail.com',
#  'tech': ['ML', 'DL', 'cv'],
#  'plateform': ['technueron', 'kidneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#     name          mail_id tech   plateform
# 0  vijay  vijay@gmail.com   ML  technueron
# 1  vijay  vijay@gmail.com   DL   kidneuron
# 2  vijay  vijay@gmail.com   cv     ineuron

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  cv

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
 d["data"]
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
del d1['diagnosticTroubleCodeData']

# %%
 d["data"]
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)

# length of some key is not same so it is not able to make
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/46938  1225167599
# 1     https://github.com/pandas-dev/pandas/pull/46937  1224888845
# 2     https://github.com/pandas-dev/pandas/pull/46936  1224829902
# 3   https://github.com/pandas-dev/pandas/issues/46935  1224748301
# 4     https://github.com/pandas-dev/pandas/pull/46934  1224564144
# 5   https://github.com/pandas-dev/pandas/issues/46933  1224248446
# 6     https://github.com/pandas-dev/pandas/pull/46932  1223430815
# 7     https://github.com/pandas-dev/pandas/pull/46931  1223420483
# 8     https://github.com/pandas-dev/pandas/pull/46929  1223381879
# 9     https://github.com/pandas-dev/pandas/pull/46928  1223324439
# 10  https://github.com/pandas-dev/pandas/issues/46924  1222957102
# 11  https://github.com/pandas-dev/pandas/issues/46923  1222682814
# 12    https://github.com/pandas-dev/pandas/pull/46919  1222211412
# 13  https://github.com/pandas-dev/pandas/issues/46916  1222178317
# 14    https://github.com/pandas-dev/pandas/pull/46914  1222014732
# 15  https://github.com/pandas-dev/pandas/issues/46910  1221938636
# 16  https://github.com/pandas-dev/pandas/issues/46909  1221937554
# 17    https://github.com/pandas-dev/pandas/pull/46906  1221860584
# 18    https://github.com/pandas-dev/pandas/pull/46905  1221828150
# 19  https://github.com/pandas-dev/pandas/issues/46904  1221734240
# 20    https://github.com/pandas-dev/pandas/pull/46903  1221694919
# 21    https://github.com/pandas-dev/pandas/pull/46902  1221687570
# 22    https://github.com/pandas-dev/pandas/pull/46901  1221685599
# 23  https://github.com/pandas-dev/pandas/issues/46900  1221678412
# 24  https://github.com/pandas-dev/pandas/issues/46896  1221383537
# 25  https://github.com/pandas-dev/pandas/issues/46895  1219996829
# 26    https://github.com/pandas-dev/pandas/pull/46894  1219860886
# 27    https://github.com/pandas-dev/pandas/pull/46892  1219301794
# 28  https://github.com/pandas-dev/pandas/issues/46891  1218999811
# 29  https://github.com/pandas-dev/pandas/issues/46890  1218658465
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD843R77q   46938
# 1   PR_kwDOAA0YD843RCS9   46937
# 2   PR_kwDOAA0YD843Q2bK   46936
# 3    I_kwDOAA0YD85JAC0N   46935
# 4   PR_kwDOAA0YD843QEUl   46934
# 5    I_kwDOAA0YD85I-Ix-   46933
# 6   PR_kwDOAA0YD843Mh7S   46932
# 7   PR_kwDOAA0YD843MfqR   46931
# 8   PR_kwDOAA0YD843MXXS   46929
# 9   PR_kwDOAA0YD843MK94   46928
# 10   I_kwDOAA0YD85I5Ngu   46924
# 11   I_kwDOAA0YD85I4Ki-   46923
# 12  PR_kwDOAA0YD843IfHA   46919
# 13   I_kwDOAA0YD85I2PYN   46916
# 14  PR_kwDOAA0YD843H27h   46914
# 15   I_kwDOAA0YD85I1U3M   46910
# 16   I_kwDOAA0YD85I1UmS   46909
# 17  PR_kwDOAA0YD843HYDH   46906
# 18  PR_kwDOAA0YD843HSFc   46905
# 19   I_kwDOAA0YD85I0i9g   46904
# 20  PR_kwDOAA0YD843G4eN   46903
# 21  PR_kwDOAA0YD843G2_s   46902
# 22  PR_kwDOAA0YD843G2nd   46901
# 23   I_kwDOAA0YD85I0VVM   46900
# 24   I_kwDOAA0YD85IzNVx   46896
# 25   I_kwDOAA0YD85It6yd   46895
# 26  PR_kwDOAA0YD843AhMl   46894
# 27  PR_kwDOAA0YD842-gXD   46892
# 28   I_kwDOAA0YD85IqHYD   46891
# 29   I_kwDOAA0YD85Io0Ch   46890
#
#                                                 title  ...  \
# 0   ENH: validates boolean kwargs in DataFrame and...  ...
# 1                     TYP: towards reportUnusedImport  ...
# 2               Add/reorganize scalar Timedelta tests  ...
# 3   BUG: `pd.read_json` throwing error on `bytes` ...  ...
# 4     PERF: Remove docstrings from inline cython code  ...
# 5   ENH: pandas.DataFrame.to_sql - if_exists repla...  ...
# 6                  ENH: support mask in libalgos.rank  ...
# 7   DOC: added index, dropna description for HDF m...  ...
# 8   TYP: overload maybe_downcast_numeric and maybe...  ...
# 9   TYP: resolve ignored mypy errors in core/descr...  ...
# 10  ENH: implement `nlargest` and `nsmallest` for ...  ...
# 11  QST: Problem in output excel with big float nu...  ...
# 12                    TYP: fix MultiIndex._names type  ...
# 13  BUG:  Groupby does not work with mean/sum func...  ...
# 14  TYP: fix type annotation in _has_externally_sh...  ...
# 15  Deprecate na_sentinel being None in pd.factori...  ...
# 16  CLN:  handling of categorical with dropna=Fals...  ...
# 17  DEPR: numeric_only default in DataFrame method...  ...
# 18                          TYP/CI: bump mypy&pyright  ...
# 19  BUG: aggregate function on transposed resample...  ...
# 20  BUG: DatetimeIndex.resolution with nanosecond ...  ...
# 21   ENH: fields.get_start_end_field support non-nano  ...
# 22  ENH: allow non-nano in DatetimeArray, Timedelt...  ...
# 23  BUG: `MultiIndex.dtypes` index behavior change...  ...
# 24  BUG: incorrect type when casting to nullable t...  ...
# 25   Leading zeros in data for read_excel vs read_csv  ...
# 26                    PERF: Optimize read_excel nrows  ...
# 27  BUG: rolling aggregate() with a list of functi...  ...
# 28                                              BUG:   ...
# 29                         BUG: Error while debugging  ...
#
#                   updated_at closed_at author_association  active_lock_reason  \
# 0  2022-05-04 10:08:12+00:00       NaT               NONE                 NaN
# 1  2022-05-04 03:34:35+00:00       NaT        CONTRIBUTOR                 NaN
# 2  2022-05-04 01:42:05+00:00       NaT               NONE                 NaN
# 3  2022-05-04 09:53:21+00:00       NaT               NONE                 NaN
# 4  2022-05-04 00:01:28+00:00       NaT               NONE                 NaN
# 5  2022-05-04 09:51:18+00:00       NaT               NONE                 NaN
# 6  2022-05-04 02:31:49+00:00       NaT             MEMBER                 NaN
# 7  2022-05-02 22:40:48+00:00       NaT               NONE                 NaN
# 8  2022-05-03 17:59:10+00:00       NaT               NONE                 NaN
# 9  2022-05-03 16:03:18+00:00       NaT               NONE                 NaN
# 10 2022-05-04 09:52:26+00:00       NaT               NONE                 NaN
# 11 2022-05-04 09:52:54+00:00       NaT               NONE                 NaN
# 12 2022-05-02 20:36:25+00:00       NaT               NONE                 NaN
# 13 2022-05-04 09:53:29+00:00       NaT               NONE                 NaN
# 14 2022-05-03 01:29:00+00:00       NaT        CONTRIBUTOR                 NaN
# 15 2022-05-02 21:32:25+00:00       NaT             MEMBER                 NaN
# 16 2022-04-30 22:51:26+00:00       NaT             MEMBER                 NaN
# 17 2022-05-03 13:20:30+00:00       NaT             MEMBER                 NaN
# 18 2022-05-02 23:12:13+00:00       NaT        CONTRIBUTOR                 NaN
# 19 2022-05-04 08:30:26+00:00       NaT               NONE                 NaN
# 20 2022-05-02 23:49:39+00:00       NaT             MEMBER                 NaN
# 21 2022-05-02 20:32:23+00:00       NaT             MEMBER                 NaN
# 22 2022-04-30 17:57:37+00:00       NaT             MEMBER                 NaN
# 23 2022-05-04 08:44:34+00:00       NaT        CONTRIBUTOR                 NaN
# 24 2022-05-04 09:28:15+00:00       NaT               NONE                 NaN
# 25 2022-05-03 19:10:06+00:00       NaT               NONE                 NaN
# 26 2022-04-30 03:32:21+00:00       NaT        CONTRIBUTOR                 NaN
# 27 2022-05-04 04:44:35+00:00       NaT               NONE                 NaN
# 28 2022-05-04 09:50:13+00:00       NaT               NONE                 NaN
# 29 2022-05-04 10:09:14+00:00       NaT               NONE                 NaN
#
#    draft                                       pull_request  \
# 0    1.0  {'url': 'https://api.github.com/repos/pandas-d...
# 1    1.0  {'url': 'https://api.github.com/repos/pandas-d...
# 2    0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 3    NaN                                                NaN
# 4    0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 5    NaN                                                NaN
# 6    0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 7    0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 8    0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 9    0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 10   NaN                                                NaN
# 11   NaN                                                NaN
# 12   0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 13   NaN                                                NaN
# 14   0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 15   NaN                                                NaN
# 16   NaN                                                NaN
# 17   0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 18   1.0  {'url': 'https://api.github.com/repos/pandas-d...
# 19   NaN                                                NaN
# 20   0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 21   0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 22   0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 23   NaN                                                NaN
# 24   NaN                                                NaN
# 25   NaN                                                NaN
# 26   0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 27   0.0  {'url': 'https://api.github.com/repos/pandas-d...
# 28   NaN                                                NaN
# 29   NaN                                                NaN
#
#                                                  body  \
# 0   - [X] closes #16714 (for DataFrame and Series)...
# 1   pyright's reportUnusedImport checks py and pyi...
# 2   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 3   ### Pandas version checks\n\n- [X] I have chec...
# 4   These functions aren't externally available, a...
# 5   Hi everyone! \r\n\r\nI recently had an issue w...
# 6   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 7   - [ ] closes #45030\r\n- [ ] [Tests added and ...
# 8   xref https://github.com/pandas-dev/pandas/issu...
# 9   xref https://github.com/pandas-dev/pandas/issu...
# 10  The `DataFrameGroupBy` should get a new method...
# 11  ### Research\n\n- [X] I have searched the [[pa...
# 12  - [x] xref https://github.com/pandas-dev/panda...
# 13  ### Pandas version checks\r\n\r\n- [X] I have ...
# 14  `from matplotlib import axes` is a module, not...
# 15  Currently specifying `na_sentinel=None` in pd....
# 16  #46601 fixed using categorical with dropna=Fal...
# 17  - [x] closes #46852 (Replace xxxx with the Git...
# 18               Mypy aims to have a monthly release.
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 21  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 22  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 23  ### Pandas version checks\r\n\r\n- [X] I have ...
# 24  ### Pandas version checks\n\n- [X] I have chec...
# 25  input file is 6 random zip codes. the first on...
# 26  - [x] closes #32727\r\n- [x] [Tests added and ...
# 27  - [x] closes #46132 (Replace xxxx with the Git...
# 28  ### Pandas version checks\n\n- [X] I have chec...
# 29  ### Pandas version checks\r\n\r\n- [X] I have ...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url performed_via_github_app
# 0   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 1   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 2   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 3   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 4   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 5   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 6   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 7   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 8   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 9   https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 10  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 11  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 12  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 13  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 14  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 15  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 16  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 17  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 18  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 19  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 20  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 21  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 22  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 23  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 24  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 25  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 26  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 27  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 28  https://api.github.com/repos/pandas-dev/pandas...                      NaN
# 29  https://api.github.com/repos/pandas-dev/pandas...                      NaN
#
# [30 rows x 29 columns]

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
# request for load data

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46938',
#   'id': 1225167599,
#   'node_id': 'PR_kwDOAA0YD843R77q',
#   'number': 46938,
#   'title': 'ENH: validates boolean kwargs in DataFrame and Series methods',
#   'user': {'login': 'Condielj',
#    'id': 46547065,
#    'node_id': 'MDQ6VXNlcjQ2NTQ3MDY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46547065?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Condielj',
#    'html_url': 'https://github.com/Condielj',
#    'followers_url': 'https://api.github.com/users/Condielj/followers',
#    'following_url': 'https://api.github.com/users/Condielj/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Condielj/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Condielj/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Condielj/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Condielj/orgs',
#    'repos_url': 'https://api.github.com/users/Condielj/repos',
#    'events_url': 'https://api.github.com/users/Condielj/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Condielj/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-05-04T10:08:07Z',
#   'updated_at': '2022-05-04T10:08:12Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46938',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46938',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46938.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46938.patch',
#    'merged_at': None},
#   'body': "- [X] closes #16714 (for DataFrame and Series)\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] pre commit code check passed\r\n- [X] Added an entry in the latest whatsnew.\r\n\r\n(First commit is an extra frame.py and the second is deleting it- all frame.py's are in the right place)\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46937',
#   'id': 1224888845,
#   'node_id': 'PR_kwDOAA0YD843RCS9',
#   'number': 46937,
#   'title': 'TYP: towards reportUnusedImport',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-04T03:34:35Z',
#   'updated_at': '2022-05-04T03:34:35Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46937',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46937',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46937.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46937.patch',
#    'merged_at': None},
#   'body': "pyright's reportUnusedImport checks py and pyi files for unused imports. If an import is explicitly marked as public (re-exported using `as` or in `__all__`) it is used.\r\n\r\nThere are more files that have unused imports. I have not included them yet since they also define lots of constants/functions/classes. If add the imports to `__all__`, I will also need to add the public constants/functions/classes to `__all__`. I'm happy to do that, but I wanted to wait first. A simpler alternative (but I guess less consistent) option is to use `as` in these cases.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46936',
#   'id': 1224829902,
#   'node_id': 'PR_kwDOAA0YD843Q2bK',
#   'number': 46936,
#   'title': 'Add/reorganize scalar Timedelta tests',
#   'user': {'login': 'patrickmckenna',
#    'id': 3589536,
#    'node_id': 'MDQ6VXNlcjM1ODk1MzY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3589536?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/patrickmckenna',
#    'html_url': 'https://github.com/patrickmckenna',
#    'followers_url': 'https://api.github.com/users/patrickmckenna/followers',
#    'following_url': 'https://api.github.com/users/patrickmckenna/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/patrickmckenna/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/patrickmckenna/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/patrickmckenna/subscriptions',
#    'organizations_url': 'https://api.github.com/users/patrickmckenna/orgs',
#    'repos_url': 'https://api.github.com/users/patrickmckenna/repos',
#    'events_url': 'https://api.github.com/users/patrickmckenna/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/patrickmckenna/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-04T01:02:22Z',
#   'updated_at': '2022-05-04T01:42:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46936',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46936',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46936.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46936.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis is a companion of sorts to https://github.com/pandas-dev/pandas/pull/46854. It adds more thorough tests, and groups them by type, but doesn't change any behavior.\r\n\r\n/cc @jbrockmendel @jreback \r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46935',
#   'id': 1224748301,
#   'node_id': 'I_kwDOAA0YD85JAC0N',
#   'number': 46935,
#   'title': 'BUG: `pd.read_json` throwing error on `bytes` input',
#   'user': {'login': 'galipremsagar',
#    'id': 11664259,
#    'node_id': 'MDQ6VXNlcjExNjY0MjU5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11664259?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/galipremsagar',
#    'html_url': 'https://github.com/galipremsagar',
#    'followers_url': 'https://api.github.com/users/galipremsagar/followers',
#    'following_url': 'https://api.github.com/users/galipremsagar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/galipremsagar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/galipremsagar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/galipremsagar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/galipremsagar/orgs',
#    'repos_url': 'https://api.github.com/users/galipremsagar/repos',
#    'events_url': 'https://api.github.com/users/galipremsagar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/galipremsagar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/95',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95/labels',
#    'id': 7829734,
#    'node_id': 'MI_kwDOAA0YD84Ad3jm',
#    'number': 95,
#    'title': '1.4.3',
#    'description': 'on-merge: backport to 1.4.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 18,
#    'closed_issues': 34,
#    'state': 'open',
#    'created_at': '2022-04-01T18:18:24Z',
#    'updated_at': '2022-05-04T09:07:23Z',
#    'due_on': '2022-04-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2022-05-03T22:57:58Z',
#   'updated_at': '2022-05-04T09:53:21Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nIn [1]: buffer = (\r\n   ...:         b\'{"amount": 100, "name": "Alice"}\\n\'\r\n   ...:         b\'{"amount": 200, "name": "Bob"}\\n\'\r\n   ...:         b\'{"amount": 300, "name": "Charlie"}\\n\'\r\n   ...:         b\'{"amount": 400, "name": "Dennis"}\\n\'\r\n   ...:     )\r\n\r\nIn [2]: import pandas as pd\r\n\r\nIn [3]: pd.read_json(buffer)\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\nInput In [3], in <cell line: 1>()\r\n----> 1 pd.read_json(buffer)\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)\r\n    205     else:\r\n    206         kwargs[new_arg_name] = new_arg_value\r\n--> 207 return func(*args, **kwargs)\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)\r\n    305 if len(args) > num_allow_args:\r\n    306     warnings.warn(\r\n    307         msg.format(arguments=arguments),\r\n    308         FutureWarning,\r\n    309         stacklevel=stacklevel,\r\n    310     )\r\n--> 311 return func(*args, **kwargs)\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/io/json/_json.py:588, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)\r\n    585 if convert_axes is None and orient != "table":\r\n    586     convert_axes = True\r\n--> 588 json_reader = JsonReader(\r\n    589     path_or_buf,\r\n    590     orient=orient,\r\n    591     typ=typ,\r\n    592     dtype=dtype,\r\n    593     convert_axes=convert_axes,\r\n    594     convert_dates=convert_dates,\r\n    595     keep_default_dates=keep_default_dates,\r\n    596     numpy=numpy,\r\n    597     precise_float=precise_float,\r\n    598     date_unit=date_unit,\r\n    599     encoding=encoding,\r\n    600     lines=lines,\r\n    601     chunksize=chunksize,\r\n    602     compression=compression,\r\n    603     nrows=nrows,\r\n    604     storage_options=storage_options,\r\n    605     encoding_errors=encoding_errors,\r\n    606 )\r\n    608 if chunksize:\r\n    609     return json_reader\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/io/json/_json.py:673, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)\r\n    670     if not self.lines:\r\n    671         raise ValueError("nrows can only be passed if lines=True")\r\n--> 673 data = self._get_data_from_filepath(filepath_or_buffer)\r\n    674 self.data = self._preprocess_data(data)\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/io/json/_json.py:710, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)\r\n    703 filepath_or_buffer = stringify_path(filepath_or_buffer)\r\n    704 if (\r\n    705     not isinstance(filepath_or_buffer, str)\r\n    706     or is_url(filepath_or_buffer)\r\n    707     or is_fsspec_url(filepath_or_buffer)\r\n    708     or file_exists(filepath_or_buffer)\r\n    709 ):\r\n--> 710     self.handles = get_handle(\r\n    711         filepath_or_buffer,\r\n    712         "r",\r\n    713         encoding=self.encoding,\r\n    714         compression=self.compr ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46934',
#   'id': 1224564144,
#   'node_id': 'PR_kwDOAA0YD843QEUl',
#   'number': 46934,
#   'title': 'PERF: Remove docstrings from inline cython code',
#   'user': {'login': 'wlach',
#    'id': 20569,
#    'node_id': 'MDQ6VXNlcjIwNTY5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20569?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wlach',
#    'html_url': 'https://github.com/wlach',
#    'followers_url': 'https://api.github.com/users/wlach/followers',
#    'following_url': 'https://api.github.com/users/wlach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wlach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wlach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wlach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wlach/orgs',
#    'repos_url': 'https://api.github.com/users/wlach/repos',
#    'events_url': 'https://api.github.com/users/wlach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wlach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-05-03T20:00:27Z',
#   'updated_at': '2022-05-04T00:01:28Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46934',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46934',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46934.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46934.patch',
#    'merged_at': None},
#   'body': "These functions aren't externally available, and removing them saves\na small amount of space (approximately 250k in the size of the generated\n.so's on a linux64 machine).\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46933',
#   'id': 1224248446,
#   'node_id': 'I_kwDOAA0YD85I-Ix-',
#   'number': 46933,
#   'title': 'ENH: pandas.DataFrame.to_sql - if_exists replace with cascade option',
#   'user': {'login': 'r7butler',
#    'id': 40872002,
#    'node_id': 'MDQ6VXNlcjQwODcyMDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40872002?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/r7butler',
#    'html_url': 'https://github.com/r7butler',
#    'followers_url': 'https://api.github.com/users/r7butler/followers',
#    'following_url': 'https://api.github.com/users/r7butler/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/r7butler/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/r7butler/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/r7butler/subscriptions',
#    'organizations_url': 'https://api.github.com/users/r7butler/orgs',
#    'repos_url': 'https://api.github.com/users/r7butler/repos',
#    'events_url': 'https://api.github.com/users/r7butler/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/r7butler/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 47232590,
#     'node_id': 'MDU6TGFiZWw0NzIzMjU5MA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20SQL',
#     'name': 'IO SQL',
#     'color': '5319e7',
#     'default': False,
#     'description': 'to_sql, read_sql, read_sql_query'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-03T15:24:58Z',
#   'updated_at': '2022-05-04T09:51:18Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': 'Hi everyone! \r\n\r\nI recently had an issue with a script where i tried to call the to_sql method on a dataframe to put it into a table, and in this particular case, i needed to do a to_sql with if_exists = \'replace\'\r\n\r\nIt threw an error because there was a view that depended on that table, but i didnt quite care too much, so it would have been fine if the table were dropped with cascade\r\n\r\nIn the line above my call to to_sql i put "DROP TABLE __table__ CASCADE" and that solved it, but i am wondering if we can put an option in the to_sql method where there is a "cascade replace" option?\r\n\r\nHopefully this makes ense\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46932',
#   'id': 1223430815,
#   'node_id': 'PR_kwDOAA0YD843Mh7S',
#   'number': 46932,
#   'title': 'ENH: support mask in libalgos.rank',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-02T22:35:01Z',
#   'updated_at': '2022-05-04T02:31:49Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46932',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46932',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46932.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46932.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46931',
#   'id': 1223420483,
#   'node_id': 'PR_kwDOAA0YD843MfqR',
#   'number': 46931,
#   'title': 'DOC: added index, dropna description for HDF methods #45030',
#   'user': {'login': 'alexondor',
#    'id': 39064444,
#    'node_id': 'MDQ6VXNlcjM5MDY0NDQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39064444?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexondor',
#    'html_url': 'https://github.com/alexondor',
#    'followers_url': 'https://api.github.com/users/alexondor/followers',
#    'following_url': 'https://api.github.com/users/alexondor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alexondor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alexondor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alexondor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alexondor/orgs',
#    'repos_url': 'https://api.github.com/users/alexondor/repos',
#    'events_url': 'https://api.github.com/users/alexondor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alexondor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-02T22:20:01Z',
#   'updated_at': '2022-05-02T22:40:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46931',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46931',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46931.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46931.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #45030\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46929',
#   'id': 1223381879,
#   'node_id': 'PR_kwDOAA0YD843MXXS',
#   'number': 46929,
#   'title': 'TYP: overload maybe_downcast_numeric and maybe_downcast_to_dtype',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-05-02T21:28:09Z',
#   'updated_at': '2022-05-03T17:59:10Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46929',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46929',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46929.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46929.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/37715\r\n\r\nOverload type definitions for these methods so that passing in an ndarray returns an ndarray.\r\nThis allows removing two more ignored mypy errors.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46928',
#   'id': 1223324439,
#   'node_id': 'PR_kwDOAA0YD843MK94',
#   'number': 46928,
#   'title': 'TYP: resolve ignored mypy errors in core/describe.py',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-02T20:26:52Z',
#   'updated_at': '2022-05-03T16:03:18Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46928',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46928',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46928.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46928.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/37715\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46924',
#   'id': 1222957102,
#   'node_id': 'I_kwDOAA0YD85I5Ngu',
#   'number': 46924,
#   'title': 'ENH: implement `nlargest` and `nsmallest` for DataFrameGroupBy like SeriesGroupBy',
#   'user': {'login': 'yoch',
#    'id': 795960,
#    'node_id': 'MDQ6VXNlcjc5NTk2MA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/795960?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yoch',
#    'html_url': 'https://github.com/yoch',
#    'followers_url': 'https://api.github.com/users/yoch/followers',
#    'following_url': 'https://api.github.com/users/yoch/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yoch/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yoch/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yoch/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yoch/orgs',
#    'repos_url': 'https://api.github.com/users/yoch/repos',
#    'events_url': 'https://api.github.com/users/yoch/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yoch/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric%20Operations',
#     'name': 'Numeric Operations',
#     'color': '006b75',
#     'default': False,
#     'description': 'Arithmetic, Comparison, and Logical operations'},
#    {'id': 1741841389,
#     'node_id': 'MDU6TGFiZWwxNzQxODQxMzg5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20-%20Consistency',
#     'name': 'API - Consistency',
#     'color': 'b60205',
#     'default': False,
#     'description': 'Internal Consistency of API/Behavior'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-05-02T14:26:18Z',
#   'updated_at': '2022-05-04T09:52:26Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "The `DataFrameGroupBy` should get a new method `nlargest` to allow selecting the N largest rows for each group.\r\n\r\nCurrently this is doable by using `df.sort_values(...).groupby(...).head(n)` but I want to use the `keep='all'` parameter of `nlargest` which cannot be obtained with `head`\r\n\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46923',
#   'id': 1222682814,
#   'node_id': 'I_kwDOAA0YD85I4Ki-',
#   'number': 46923,
#   'title': 'QST: Problem in output excel with big float numbers',
#   'user': {'login': 'brenojesusfernandes',
#    'id': 32203685,
#    'node_id': 'MDQ6VXNlcjMyMjAzNjg1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32203685?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brenojesusfernandes',
#    'html_url': 'https://github.com/brenojesusfernandes',
#    'followers_url': 'https://api.github.com/users/brenojesusfernandes/followers',
#    'following_url': 'https://api.github.com/users/brenojesusfernandes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/brenojesusfernandes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/brenojesusfernandes/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/brenojesusfernandes/subscriptions',
#    'organizations_url': 'https://api.github.com/users/brenojesusfernandes/orgs',
#    'repos_url': 'https://api.github.com/users/brenojesusfernandes/repos',
#    'events_url': 'https://api.github.com/users/brenojesusfernandes/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/brenojesusfernandes/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None},
#    {'id': 49254273,
#     'node_id': 'MDU6TGFiZWw0OTI1NDI3Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Excel',
#     'name': 'IO Excel',
#     'color': 'bfe5bf',
#     'default': False,
#     'description': 'read_excel, to_excel'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-05-02T09:38:19Z',
#   'updated_at': '2022-05-04T09:52:54Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Research\n\n- [X] I have searched the [[pandas] tag](https://stackoverflow.com/questions/tagged/pandas) on StackOverflow for similar questions.\n\n- [X] I have asked my usage related question on [StackOverflow](https://stackoverflow.com).\n\n\n### Link to question on StackOverflow\n\nhttps://stackoverflow.com/questions/72069254/pandas-to-excel-output-float-point-is-not-right\n\n### Question about pandas\n\nI have some a weird situation trying to get the output in to_excel pandas function engine.\r\n\r\nI tried to read a xlsx excel file with the number "21631706.9893399", but when a try to write in a new xlsx excel file gives me the output "21631706.98934". I tested with openpyxl and xlsxwriter but I got the same results, however if I tried to write a xls excel with xlwt engine it gives me the right answer, is there a way to read and write the same float number with these engines? I suspect there some float limitations in xlsx file, but in the xlsx input the number is fine. By the way, it is not a question about formating number, the ouput number is actually different from the original input.\r\n\r\nMy code:\r\n\r\n```\r\nimport pandas as pd\r\n\r\ndf = pd.read_excel(r\'input\\sample.xlsx\')\r\n\r\ndf.to_excel(r\'output\\excel xlsx - xlsxwriter.xlsx\', engine=\'xlsxwriter\', index=False)\r\ndf.to_excel(r\'output\\excel xlsx - openpyxl.xlsx\', engine=\'openpyxl\', index=False)\r\ndf.to_excel(r\'output\\excel xls - xlwt.xls\', engine=\'xlwt\', index=False)\r\n```\r\n[Github Example](https://github.com/brenojesusfernandes/pandas-to-excel-test)\r\n\r\nDependencies:\r\n\r\npython = "3.7.4"\r\npandas = "1.3.5"\r\nXlsxWriter = "3.0.3"\r\nopenpyxl = "3.0.9"\r\nxlwt = "1.3.0"',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46919',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46919/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46919/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46919/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46919',
#   'id': 1222211412,
#   'node_id': 'PR_kwDOAA0YD843IfHA',
#   'number': 46919,
#   'title': 'TYP: fix MultiIndex._names type',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-01T16:40:04Z',
#   'updated_at': '2022-05-02T20:36:25Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46919',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46919',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46919.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46919.patch',
#    'merged_at': None},
# ...
#    'events_url': 'https://api.github.com/users/xr-chen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xr-chen/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1045950827,
#     'node_id': 'MDU6TGFiZWwxMDQ1OTUwODI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Window',
#     'name': 'Window',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': 'rolling, ewma, expanding'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-04-28T21:11:41Z',
#   'updated_at': '2022-05-04T04:44:35Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46892',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46892',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46892.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46892.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46132 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46892/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46892/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46891',
#   'id': 1218999811,
#   'node_id': 'I_kwDOAA0YD85IqHYD',
#   'number': 46891,
#   'title': 'BUG: ',
#   'user': {'login': 'ericbmoreira',
#    'id': 58861041,
#    'node_id': 'MDQ6VXNlcjU4ODYxMDQx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58861041?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ericbmoreira',
#    'html_url': 'https://github.com/ericbmoreira',
#    'followers_url': 'https://api.github.com/users/ericbmoreira/followers',
#    'following_url': 'https://api.github.com/users/ericbmoreira/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ericbmoreira/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ericbmoreira/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ericbmoreira/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ericbmoreira/orgs',
#    'repos_url': 'https://api.github.com/users/ericbmoreira/repos',
#    'events_url': 'https://api.github.com/users/ericbmoreira/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ericbmoreira/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47232590,
#     'node_id': 'MDU6TGFiZWw0NzIzMjU5MA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20SQL',
#     'name': 'IO SQL',
#     'color': '5319e7',
#     'default': False,
#     'description': 'to_sql, read_sql, read_sql_query'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-28T16:43:58Z',
#   'updated_at': '2022-05-04T09:50:13Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport sqlalchemy\r\nimport datetime as dt\r\n\r\n# custom modules\r\nimport muni_config\r\n\r\ndef get_df():\r\n    df = pd.DataFrame(\r\n        [{\r\n            \'fills_id\': 105802017,\r\n            \'trade_date\': dt.datetime(2022,4,28,9,41,14),\r\n            \'tsy_id\': \'CT5\',\r\n            \'avg_prc\': 99.545089,\r\n            \'yr_string\': \'five\',\r\n            \'ytw\': 2.848337\r\n        }]\r\n    )\r\n\r\n    return df\r\n\r\ndef write_fills_tsy_spots(df: pd.DataFrame):\r\n    write_data = df[[\'fills_id\', \'tsy_id\', \'avg_prc\', \'ytw\', \'yr_string\']]\r\n\r\n    with muni_config.new_get_db_conn(muni_config.muni_write) as conn:\r\n        write_data.to_sql(\r\n            \'fills_tsy_spots\',\r\n            conn,\r\n            if_exists=\'append\',\r\n            index=False,\r\n            method=mysql_update_on_dupe_key\r\n        )\r\n\r\n    return df\r\n\r\ndef mysql_update_on_dupe_key(table, conn, keys, data_iter):\r\n    data = [dict(zip(keys, val)) for val in data_iter]\r\n    stmt = sqlalchemy.dialects.mysql.insert(table.table).values(data)\r\n    update_stmt = stmt.on_duplicate_key_update(**dict(zip(stmt.inserted.keys(),\r\n        stmt.inserted.values())))\r\n    conn.execute(update_stmt)\r\n\r\n    return mysql_update_on_dupe_key\r\n\r\nif __name__ == \'__main__\':\r\n    df = get_df()\r\n    write_fills_tsy_spots(df)\n```\n\n\n### Issue Description\n\ndf.to_sql fails when a method is passed for updating on duplicate keys. New code was added to check the total_inserted against the num_inserted between 1.3.1 and 1.4.2. I suppose I should have reproducible code that would show a sqllite table creation, etc.. Hopefully this is enough code to understand my bug report.\r\n\r\nA TypeError is returned:\r\n```\r\nFile "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\core\\generic.py", line 2951, in to_sql\r\n    return sql.to_sql(\r\n  File "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\io\\sql.py", line 697, in to_sql\r\n    return pandas_sql.to_sql(\r\n  File "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\io\\sql.py", line 1739, in to_sql\r\n    total_inserted = sql_engine.insert_records(\r\n  File "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\io\\sql.py", line 1322, in insert_records\r\n    return table.insert(chunksize=chunksize, method=method)\r\n  File "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\io\\sql.py", line 954, in insert\r\n    total_inserted += num_inserted\r\nTypeError: unsupported operand type(s) for +=: \'int\' and \'function\'\r\n```\r\n\r\nBecause this code block at line 951 in sql.py.\r\n```\r\n                if num_inserted is None:\r\n                    total_inserted = None\r\n                else:\r\n                    total_inserted += num_inserted\r\n```\r\n\r\nIf I change it to the following, it works.:\r\n```\r\n                if num_inserted is None or callable(num_inserted):\r\n                    total_inserted = None\r\n                else:\r\n                    total_inserted += num_inserted\r\n```\r\n\n\n### Expected Behavior\n\nNot raise a TypeError when a method is passed.\r\n\r\nChange line 951 in sql.py.\r\n```if num_inserted is None or callable(num_inserted):```\r\n\n\n### Installed Versions\n\nWorking pd.show_versions:\r\n\r\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : c7f7443c1bad8262358114d5e88cd9c8a308e8aa\r\npython           : 3.9.6.final.0\r\npython-bits      : 64\r\nOS              ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46890',
#   'id': 1218658465,
#   'node_id': 'I_kwDOAA0YD85Io0Ch',
#   'number': 46890,
#   'title': 'BUG: Error while debugging',
#   'user': {'login': 'eddaz7',
#    'id': 59227306,
#    'node_id': 'MDQ6VXNlcjU5MjI3MzA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59227306?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eddaz7',
#    'html_url': 'https://github.com/eddaz7',
#    'followers_url': 'https://api.github.com/users/eddaz7/followers',
#    'following_url': 'https://api.github.com/users/eddaz7/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eddaz7/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eddaz7/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eddaz7/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eddaz7/orgs',
#    'repos_url': 'https://api.github.com/users/eddaz7/repos',
#    'events_url': 'https://api.github.com/users/eddaz7/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eddaz7/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2022-04-28T12:29:43Z',
#   'updated_at': '2022-05-04T10:09:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\ndf = pd.DataFrame()\r\ndf[\'col1\'] = np.random.rand(100)\r\ndf[\'col2\'] = np.random.rand(100)\r\n\r\ndf.to_parquet(\'test.parquet\')\r\n\r\ndf = pd.read_parquet(\'test.parquet\')\r\n\r\nprint(df)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIMPORTANT: This only happens when debugging on line: pd.read_parquet(\'test.parquet\')\r\nI am using spyder on anaconda.\r\nI can provide dependencies if necessary.\r\n\r\n<details>\r\nTraceback (most recent call last):\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\spyder_kernels\\customize\\spyderpdb.py", line 776, in run\r\n    super(SpyderPdb, self).run(cmd, globals, locals)\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\bdb.py", line 597, in run\r\n    exec(cmd, globals, locals)\r\n\r\n  File "c:\\users\\edudv\\downloads\\test.py", line 16, in <module>\r\n    df = pd.read_parquet(\'test.parquet\')\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\io\\parquet.py", line 493, in read_parquet\r\n    return impl.read(\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\io\\parquet.py", line 240, in read\r\n    result = self.api.parquet.read_table(\r\n\r\n  File "pyarrow\\array.pxi", line 767, in pyarrow.lib._PandasConvertible.to_pandas\r\n\r\n  File "pyarrow\\table.pxi", line 1996, in pyarrow.lib.Table._to_pandas\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pyarrow\\pandas_compat.py", line 788, in table_to_blockmanager\r\n    columns = _deserialize_column_index(table, all_columns, column_indexes)\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pyarrow\\pandas_compat.py", line 903, in _deserialize_column_index\r\n    columns = _flatten_single_level_multiindex(columns)\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pyarrow\\pandas_compat.py", line 1150, in _flatten_single_level_multiindex\r\n    if not index.is_unique:\r\n\r\n  File "pandas\\_libs\\properties.pyx", line 37, in pandas._libs.properties.CachedProperty.__get__\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\core\\indexes\\base.py", line 2237, in is_unique\r\n    return self._engine.is_unique\r\n\r\n  File "pandas\\_libs\\properties.pyx", line 37, in pandas._libs.properties.CachedProperty.__get__\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\core\\indexes\\multi.py", line 1097, in _engine\r\n    return MultiIndexUIntEngine(self.levels, self.codes, offsets)\r\n\r\n  File "pandas\\_libs\\index.pyx", line 635, in pandas._libs.index.BaseMultiIndexCodesEngine.__init__\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\core\\indexes\\multi.py", line 136, in _codes_to_ints\r\n    codes <<= self.offsets\r\n\r\nAttributeError: \'MultiIndex\' object has no attribute \'offsets\'\r\n\r\n</details>\r\n\r\n### Expected Behavior\r\n\r\nRead parquet file\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 4bfe3d07b4858144c219b9346329027024102ab6\r\npython           : 3.10.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 60 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en\r\nLOCALE           : es_ES.cp1252\r\n\r\npandas      ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/timeline',
#   'performed_via_github_app': None}]

# %%
len(data1)
# Out:
# 30

# %%
for i in range (len(data1)):
    print(data1[0]['user']['id'])
# Out:
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065
# 46547065

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46938',
#   'id': 1225167599,
#   'node_id': 'PR_kwDOAA0YD843R77q',
#   'number': 46938,
#   'title': 'ENH: validates boolean kwargs in DataFrame and Series methods',
#   'user': {'login': 'Condielj',
#    'id': 46547065,
#    'node_id': 'MDQ6VXNlcjQ2NTQ3MDY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46547065?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Condielj',
#    'html_url': 'https://github.com/Condielj',
#    'followers_url': 'https://api.github.com/users/Condielj/followers',
#    'following_url': 'https://api.github.com/users/Condielj/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Condielj/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Condielj/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Condielj/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Condielj/orgs',
#    'repos_url': 'https://api.github.com/users/Condielj/repos',
#    'events_url': 'https://api.github.com/users/Condielj/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Condielj/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-05-04T10:08:07Z',
#   'updated_at': '2022-05-04T10:08:12Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46938',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46938',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46938.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46938.patch',
#    'merged_at': None},
#   'body': "- [X] closes #16714 (for DataFrame and Series)\r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] pre commit code check passed\r\n- [X] Added an entry in the latest whatsnew.\r\n\r\n(First commit is an extra frame.py and the second is deleting it- all frame.py's are in the right place)\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46938/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46937',
#   'id': 1224888845,
#   'node_id': 'PR_kwDOAA0YD843RCS9',
#   'number': 46937,
#   'title': 'TYP: towards reportUnusedImport',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-04T03:34:35Z',
#   'updated_at': '2022-05-04T03:34:35Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46937',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46937',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46937.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46937.patch',
#    'merged_at': None},
#   'body': "pyright's reportUnusedImport checks py and pyi files for unused imports. If an import is explicitly marked as public (re-exported using `as` or in `__all__`) it is used.\r\n\r\nThere are more files that have unused imports. I have not included them yet since they also define lots of constants/functions/classes. If add the imports to `__all__`, I will also need to add the public constants/functions/classes to `__all__`. I'm happy to do that, but I wanted to wait first. A simpler alternative (but I guess less consistent) option is to use `as` in these cases.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46937/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46936',
#   'id': 1224829902,
#   'node_id': 'PR_kwDOAA0YD843Q2bK',
#   'number': 46936,
#   'title': 'Add/reorganize scalar Timedelta tests',
#   'user': {'login': 'patrickmckenna',
#    'id': 3589536,
#    'node_id': 'MDQ6VXNlcjM1ODk1MzY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3589536?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/patrickmckenna',
#    'html_url': 'https://github.com/patrickmckenna',
#    'followers_url': 'https://api.github.com/users/patrickmckenna/followers',
#    'following_url': 'https://api.github.com/users/patrickmckenna/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/patrickmckenna/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/patrickmckenna/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/patrickmckenna/subscriptions',
#    'organizations_url': 'https://api.github.com/users/patrickmckenna/orgs',
#    'repos_url': 'https://api.github.com/users/patrickmckenna/repos',
#    'events_url': 'https://api.github.com/users/patrickmckenna/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/patrickmckenna/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-04T01:02:22Z',
#   'updated_at': '2022-05-04T01:42:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46936',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46936',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46936.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46936.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis is a companion of sorts to https://github.com/pandas-dev/pandas/pull/46854. It adds more thorough tests, and groups them by type, but doesn't change any behavior.\r\n\r\n/cc @jbrockmendel @jreback \r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46936/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46935',
#   'id': 1224748301,
#   'node_id': 'I_kwDOAA0YD85JAC0N',
#   'number': 46935,
#   'title': 'BUG: `pd.read_json` throwing error on `bytes` input',
#   'user': {'login': 'galipremsagar',
#    'id': 11664259,
#    'node_id': 'MDQ6VXNlcjExNjY0MjU5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11664259?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/galipremsagar',
#    'html_url': 'https://github.com/galipremsagar',
#    'followers_url': 'https://api.github.com/users/galipremsagar/followers',
#    'following_url': 'https://api.github.com/users/galipremsagar/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/galipremsagar/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/galipremsagar/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/galipremsagar/subscriptions',
#    'organizations_url': 'https://api.github.com/users/galipremsagar/orgs',
#    'repos_url': 'https://api.github.com/users/galipremsagar/repos',
#    'events_url': 'https://api.github.com/users/galipremsagar/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/galipremsagar/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/95',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95/labels',
#    'id': 7829734,
#    'node_id': 'MI_kwDOAA0YD84Ad3jm',
#    'number': 95,
#    'title': '1.4.3',
#    'description': 'on-merge: backport to 1.4.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 18,
#    'closed_issues': 34,
#    'state': 'open',
#    'created_at': '2022-04-01T18:18:24Z',
#    'updated_at': '2022-05-04T09:07:23Z',
#    'due_on': '2022-04-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2022-05-03T22:57:58Z',
#   'updated_at': '2022-05-04T09:53:21Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nIn [1]: buffer = (\r\n   ...:         b\'{"amount": 100, "name": "Alice"}\\n\'\r\n   ...:         b\'{"amount": 200, "name": "Bob"}\\n\'\r\n   ...:         b\'{"amount": 300, "name": "Charlie"}\\n\'\r\n   ...:         b\'{"amount": 400, "name": "Dennis"}\\n\'\r\n   ...:     )\r\n\r\nIn [2]: import pandas as pd\r\n\r\nIn [3]: pd.read_json(buffer)\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\nInput In [3], in <cell line: 1>()\r\n----> 1 pd.read_json(buffer)\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)\r\n    205     else:\r\n    206         kwargs[new_arg_name] = new_arg_value\r\n--> 207 return func(*args, **kwargs)\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)\r\n    305 if len(args) > num_allow_args:\r\n    306     warnings.warn(\r\n    307         msg.format(arguments=arguments),\r\n    308         FutureWarning,\r\n    309         stacklevel=stacklevel,\r\n    310     )\r\n--> 311 return func(*args, **kwargs)\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/io/json/_json.py:588, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)\r\n    585 if convert_axes is None and orient != "table":\r\n    586     convert_axes = True\r\n--> 588 json_reader = JsonReader(\r\n    589     path_or_buf,\r\n    590     orient=orient,\r\n    591     typ=typ,\r\n    592     dtype=dtype,\r\n    593     convert_axes=convert_axes,\r\n    594     convert_dates=convert_dates,\r\n    595     keep_default_dates=keep_default_dates,\r\n    596     numpy=numpy,\r\n    597     precise_float=precise_float,\r\n    598     date_unit=date_unit,\r\n    599     encoding=encoding,\r\n    600     lines=lines,\r\n    601     chunksize=chunksize,\r\n    602     compression=compression,\r\n    603     nrows=nrows,\r\n    604     storage_options=storage_options,\r\n    605     encoding_errors=encoding_errors,\r\n    606 )\r\n    608 if chunksize:\r\n    609     return json_reader\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/io/json/_json.py:673, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)\r\n    670     if not self.lines:\r\n    671         raise ValueError("nrows can only be passed if lines=True")\r\n--> 673 data = self._get_data_from_filepath(filepath_or_buffer)\r\n    674 self.data = self._preprocess_data(data)\r\n\r\nFile /nvme/0/pgali/envs/cudfdev/lib/python3.8/site-packages/pandas/io/json/_json.py:710, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)\r\n    703 filepath_or_buffer = stringify_path(filepath_or_buffer)\r\n    704 if (\r\n    705     not isinstance(filepath_or_buffer, str)\r\n    706     or is_url(filepath_or_buffer)\r\n    707     or is_fsspec_url(filepath_or_buffer)\r\n    708     or file_exists(filepath_or_buffer)\r\n    709 ):\r\n--> 710     self.handles = get_handle(\r\n    711         filepath_or_buffer,\r\n    712         "r",\r\n    713         encoding=self.encoding,\r\n    714         compression=self.compr ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46935/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46934',
#   'id': 1224564144,
#   'node_id': 'PR_kwDOAA0YD843QEUl',
#   'number': 46934,
#   'title': 'PERF: Remove docstrings from inline cython code',
#   'user': {'login': 'wlach',
#    'id': 20569,
#    'node_id': 'MDQ6VXNlcjIwNTY5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20569?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wlach',
#    'html_url': 'https://github.com/wlach',
#    'followers_url': 'https://api.github.com/users/wlach/followers',
#    'following_url': 'https://api.github.com/users/wlach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wlach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wlach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wlach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wlach/orgs',
#    'repos_url': 'https://api.github.com/users/wlach/repos',
#    'events_url': 'https://api.github.com/users/wlach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wlach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-05-03T20:00:27Z',
#   'updated_at': '2022-05-04T00:01:28Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46934',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46934',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46934.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46934.patch',
#    'merged_at': None},
#   'body': "These functions aren't externally available, and removing them saves\na small amount of space (approximately 250k in the size of the generated\n.so's on a linux64 machine).\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46934/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46933',
#   'id': 1224248446,
#   'node_id': 'I_kwDOAA0YD85I-Ix-',
#   'number': 46933,
#   'title': 'ENH: pandas.DataFrame.to_sql - if_exists replace with cascade option',
#   'user': {'login': 'r7butler',
#    'id': 40872002,
#    'node_id': 'MDQ6VXNlcjQwODcyMDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40872002?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/r7butler',
#    'html_url': 'https://github.com/r7butler',
#    'followers_url': 'https://api.github.com/users/r7butler/followers',
#    'following_url': 'https://api.github.com/users/r7butler/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/r7butler/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/r7butler/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/r7butler/subscriptions',
#    'organizations_url': 'https://api.github.com/users/r7butler/orgs',
#    'repos_url': 'https://api.github.com/users/r7butler/repos',
#    'events_url': 'https://api.github.com/users/r7butler/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/r7butler/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 47232590,
#     'node_id': 'MDU6TGFiZWw0NzIzMjU5MA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20SQL',
#     'name': 'IO SQL',
#     'color': '5319e7',
#     'default': False,
#     'description': 'to_sql, read_sql, read_sql_query'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-03T15:24:58Z',
#   'updated_at': '2022-05-04T09:51:18Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': 'Hi everyone! \r\n\r\nI recently had an issue with a script where i tried to call the to_sql method on a dataframe to put it into a table, and in this particular case, i needed to do a to_sql with if_exists = \'replace\'\r\n\r\nIt threw an error because there was a view that depended on that table, but i didnt quite care too much, so it would have been fine if the table were dropped with cascade\r\n\r\nIn the line above my call to to_sql i put "DROP TABLE __table__ CASCADE" and that solved it, but i am wondering if we can put an option in the to_sql method where there is a "cascade replace" option?\r\n\r\nHopefully this makes ense\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46933/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46932',
#   'id': 1223430815,
#   'node_id': 'PR_kwDOAA0YD843Mh7S',
#   'number': 46932,
#   'title': 'ENH: support mask in libalgos.rank',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-02T22:35:01Z',
#   'updated_at': '2022-05-04T02:31:49Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46932',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46932',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46932.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46932.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46932/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46931',
#   'id': 1223420483,
#   'node_id': 'PR_kwDOAA0YD843MfqR',
#   'number': 46931,
#   'title': 'DOC: added index, dropna description for HDF methods #45030',
#   'user': {'login': 'alexondor',
#    'id': 39064444,
#    'node_id': 'MDQ6VXNlcjM5MDY0NDQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39064444?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexondor',
#    'html_url': 'https://github.com/alexondor',
#    'followers_url': 'https://api.github.com/users/alexondor/followers',
#    'following_url': 'https://api.github.com/users/alexondor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/alexondor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/alexondor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/alexondor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/alexondor/orgs',
#    'repos_url': 'https://api.github.com/users/alexondor/repos',
#    'events_url': 'https://api.github.com/users/alexondor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/alexondor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-02T22:20:01Z',
#   'updated_at': '2022-05-02T22:40:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46931',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46931',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46931.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46931.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #45030\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46931/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46929',
#   'id': 1223381879,
#   'node_id': 'PR_kwDOAA0YD843MXXS',
#   'number': 46929,
#   'title': 'TYP: overload maybe_downcast_numeric and maybe_downcast_to_dtype',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-05-02T21:28:09Z',
#   'updated_at': '2022-05-03T17:59:10Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46929',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46929',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46929.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46929.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/37715\r\n\r\nOverload type definitions for these methods so that passing in an ndarray returns an ndarray.\r\nThis allows removing two more ignored mypy errors.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46929/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46928',
#   'id': 1223324439,
#   'node_id': 'PR_kwDOAA0YD843MK94',
#   'number': 46928,
#   'title': 'TYP: resolve ignored mypy errors in core/describe.py',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-02T20:26:52Z',
#   'updated_at': '2022-05-03T16:03:18Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46928',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46928',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46928.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46928.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/37715\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46928/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46924',
#   'id': 1222957102,
#   'node_id': 'I_kwDOAA0YD85I5Ngu',
#   'number': 46924,
#   'title': 'ENH: implement `nlargest` and `nsmallest` for DataFrameGroupBy like SeriesGroupBy',
#   'user': {'login': 'yoch',
#    'id': 795960,
#    'node_id': 'MDQ6VXNlcjc5NTk2MA==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/795960?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yoch',
#    'html_url': 'https://github.com/yoch',
#    'followers_url': 'https://api.github.com/users/yoch/followers',
#    'following_url': 'https://api.github.com/users/yoch/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yoch/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yoch/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yoch/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yoch/orgs',
#    'repos_url': 'https://api.github.com/users/yoch/repos',
#    'events_url': 'https://api.github.com/users/yoch/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yoch/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric%20Operations',
#     'name': 'Numeric Operations',
#     'color': '006b75',
#     'default': False,
#     'description': 'Arithmetic, Comparison, and Logical operations'},
#    {'id': 1741841389,
#     'node_id': 'MDU6TGFiZWwxNzQxODQxMzg5',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20-%20Consistency',
#     'name': 'API - Consistency',
#     'color': 'b60205',
#     'default': False,
#     'description': 'Internal Consistency of API/Behavior'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-05-02T14:26:18Z',
#   'updated_at': '2022-05-04T09:52:26Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "The `DataFrameGroupBy` should get a new method `nlargest` to allow selecting the N largest rows for each group.\r\n\r\nCurrently this is doable by using `df.sort_values(...).groupby(...).head(n)` but I want to use the `keep='all'` parameter of `nlargest` which cannot be obtained with `head`\r\n\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46924/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46923',
#   'id': 1222682814,
#   'node_id': 'I_kwDOAA0YD85I4Ki-',
#   'number': 46923,
#   'title': 'QST: Problem in output excel with big float numbers',
#   'user': {'login': 'brenojesusfernandes',
#    'id': 32203685,
#    'node_id': 'MDQ6VXNlcjMyMjAzNjg1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32203685?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brenojesusfernandes',
#    'html_url': 'https://github.com/brenojesusfernandes',
#    'followers_url': 'https://api.github.com/users/brenojesusfernandes/followers',
#    'following_url': 'https://api.github.com/users/brenojesusfernandes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/brenojesusfernandes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/brenojesusfernandes/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/brenojesusfernandes/subscriptions',
#    'organizations_url': 'https://api.github.com/users/brenojesusfernandes/orgs',
#    'repos_url': 'https://api.github.com/users/brenojesusfernandes/repos',
#    'events_url': 'https://api.github.com/users/brenojesusfernandes/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/brenojesusfernandes/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None},
#    {'id': 49254273,
#     'node_id': 'MDU6TGFiZWw0OTI1NDI3Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Excel',
#     'name': 'IO Excel',
#     'color': 'bfe5bf',
#     'default': False,
#     'description': 'read_excel, to_excel'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-05-02T09:38:19Z',
#   'updated_at': '2022-05-04T09:52:54Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Research\n\n- [X] I have searched the [[pandas] tag](https://stackoverflow.com/questions/tagged/pandas) on StackOverflow for similar questions.\n\n- [X] I have asked my usage related question on [StackOverflow](https://stackoverflow.com).\n\n\n### Link to question on StackOverflow\n\nhttps://stackoverflow.com/questions/72069254/pandas-to-excel-output-float-point-is-not-right\n\n### Question about pandas\n\nI have some a weird situation trying to get the output in to_excel pandas function engine.\r\n\r\nI tried to read a xlsx excel file with the number "21631706.9893399", but when a try to write in a new xlsx excel file gives me the output "21631706.98934". I tested with openpyxl and xlsxwriter but I got the same results, however if I tried to write a xls excel with xlwt engine it gives me the right answer, is there a way to read and write the same float number with these engines? I suspect there some float limitations in xlsx file, but in the xlsx input the number is fine. By the way, it is not a question about formating number, the ouput number is actually different from the original input.\r\n\r\nMy code:\r\n\r\n```\r\nimport pandas as pd\r\n\r\ndf = pd.read_excel(r\'input\\sample.xlsx\')\r\n\r\ndf.to_excel(r\'output\\excel xlsx - xlsxwriter.xlsx\', engine=\'xlsxwriter\', index=False)\r\ndf.to_excel(r\'output\\excel xlsx - openpyxl.xlsx\', engine=\'openpyxl\', index=False)\r\ndf.to_excel(r\'output\\excel xls - xlwt.xls\', engine=\'xlwt\', index=False)\r\n```\r\n[Github Example](https://github.com/brenojesusfernandes/pandas-to-excel-test)\r\n\r\nDependencies:\r\n\r\npython = "3.7.4"\r\npandas = "1.3.5"\r\nXlsxWriter = "3.0.3"\r\nopenpyxl = "3.0.9"\r\nxlwt = "1.3.0"',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46923/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46919',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46919/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46919/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46919/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46919',
#   'id': 1222211412,
#   'node_id': 'PR_kwDOAA0YD843IfHA',
#   'number': 46919,
#   'title': 'TYP: fix MultiIndex._names type',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-01T16:40:04Z',
#   'updated_at': '2022-05-02T20:36:25Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46919',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46919',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46919.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46919.patch',
#    'merged_at': None},
# ...
#    'events_url': 'https://api.github.com/users/xr-chen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xr-chen/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1045950827,
#     'node_id': 'MDU6TGFiZWwxMDQ1OTUwODI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Window',
#     'name': 'Window',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': 'rolling, ewma, expanding'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-04-28T21:11:41Z',
#   'updated_at': '2022-05-04T04:44:35Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46892',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46892',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46892.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46892.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46132 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46892/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46892/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46891',
#   'id': 1218999811,
#   'node_id': 'I_kwDOAA0YD85IqHYD',
#   'number': 46891,
#   'title': 'BUG: ',
#   'user': {'login': 'ericbmoreira',
#    'id': 58861041,
#    'node_id': 'MDQ6VXNlcjU4ODYxMDQx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58861041?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ericbmoreira',
#    'html_url': 'https://github.com/ericbmoreira',
#    'followers_url': 'https://api.github.com/users/ericbmoreira/followers',
#    'following_url': 'https://api.github.com/users/ericbmoreira/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ericbmoreira/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ericbmoreira/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ericbmoreira/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ericbmoreira/orgs',
#    'repos_url': 'https://api.github.com/users/ericbmoreira/repos',
#    'events_url': 'https://api.github.com/users/ericbmoreira/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ericbmoreira/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47232590,
#     'node_id': 'MDU6TGFiZWw0NzIzMjU5MA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20SQL',
#     'name': 'IO SQL',
#     'color': '5319e7',
#     'default': False,
#     'description': 'to_sql, read_sql, read_sql_query'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-04-28T16:43:58Z',
#   'updated_at': '2022-05-04T09:50:13Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport sqlalchemy\r\nimport datetime as dt\r\n\r\n# custom modules\r\nimport muni_config\r\n\r\ndef get_df():\r\n    df = pd.DataFrame(\r\n        [{\r\n            \'fills_id\': 105802017,\r\n            \'trade_date\': dt.datetime(2022,4,28,9,41,14),\r\n            \'tsy_id\': \'CT5\',\r\n            \'avg_prc\': 99.545089,\r\n            \'yr_string\': \'five\',\r\n            \'ytw\': 2.848337\r\n        }]\r\n    )\r\n\r\n    return df\r\n\r\ndef write_fills_tsy_spots(df: pd.DataFrame):\r\n    write_data = df[[\'fills_id\', \'tsy_id\', \'avg_prc\', \'ytw\', \'yr_string\']]\r\n\r\n    with muni_config.new_get_db_conn(muni_config.muni_write) as conn:\r\n        write_data.to_sql(\r\n            \'fills_tsy_spots\',\r\n            conn,\r\n            if_exists=\'append\',\r\n            index=False,\r\n            method=mysql_update_on_dupe_key\r\n        )\r\n\r\n    return df\r\n\r\ndef mysql_update_on_dupe_key(table, conn, keys, data_iter):\r\n    data = [dict(zip(keys, val)) for val in data_iter]\r\n    stmt = sqlalchemy.dialects.mysql.insert(table.table).values(data)\r\n    update_stmt = stmt.on_duplicate_key_update(**dict(zip(stmt.inserted.keys(),\r\n        stmt.inserted.values())))\r\n    conn.execute(update_stmt)\r\n\r\n    return mysql_update_on_dupe_key\r\n\r\nif __name__ == \'__main__\':\r\n    df = get_df()\r\n    write_fills_tsy_spots(df)\n```\n\n\n### Issue Description\n\ndf.to_sql fails when a method is passed for updating on duplicate keys. New code was added to check the total_inserted against the num_inserted between 1.3.1 and 1.4.2. I suppose I should have reproducible code that would show a sqllite table creation, etc.. Hopefully this is enough code to understand my bug report.\r\n\r\nA TypeError is returned:\r\n```\r\nFile "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\core\\generic.py", line 2951, in to_sql\r\n    return sql.to_sql(\r\n  File "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\io\\sql.py", line 697, in to_sql\r\n    return pandas_sql.to_sql(\r\n  File "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\io\\sql.py", line 1739, in to_sql\r\n    total_inserted = sql_engine.insert_records(\r\n  File "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\io\\sql.py", line 1322, in insert_records\r\n    return table.insert(chunksize=chunksize, method=method)\r\n  File "C:\\Users\\eric.moreira\\Miniconda3\\envs\\mquant\\lib\\site-packages\\pandas\\io\\sql.py", line 954, in insert\r\n    total_inserted += num_inserted\r\nTypeError: unsupported operand type(s) for +=: \'int\' and \'function\'\r\n```\r\n\r\nBecause this code block at line 951 in sql.py.\r\n```\r\n                if num_inserted is None:\r\n                    total_inserted = None\r\n                else:\r\n                    total_inserted += num_inserted\r\n```\r\n\r\nIf I change it to the following, it works.:\r\n```\r\n                if num_inserted is None or callable(num_inserted):\r\n                    total_inserted = None\r\n                else:\r\n                    total_inserted += num_inserted\r\n```\r\n\n\n### Expected Behavior\n\nNot raise a TypeError when a method is passed.\r\n\r\nChange line 951 in sql.py.\r\n```if num_inserted is None or callable(num_inserted):```\r\n\n\n### Installed Versions\n\nWorking pd.show_versions:\r\n\r\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : c7f7443c1bad8262358114d5e88cd9c8a308e8aa\r\npython           : 3.9.6.final.0\r\npython-bits      : 64\r\nOS              ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46891/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46890',
#   'id': 1218658465,
#   'node_id': 'I_kwDOAA0YD85Io0Ch',
#   'number': 46890,
#   'title': 'BUG: Error while debugging',
#   'user': {'login': 'eddaz7',
#    'id': 59227306,
#    'node_id': 'MDQ6VXNlcjU5MjI3MzA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59227306?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eddaz7',
#    'html_url': 'https://github.com/eddaz7',
#    'followers_url': 'https://api.github.com/users/eddaz7/followers',
#    'following_url': 'https://api.github.com/users/eddaz7/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eddaz7/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eddaz7/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eddaz7/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eddaz7/orgs',
#    'repos_url': 'https://api.github.com/users/eddaz7/repos',
#    'events_url': 'https://api.github.com/users/eddaz7/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eddaz7/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2022-04-28T12:29:43Z',
#   'updated_at': '2022-05-04T10:09:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\ndf = pd.DataFrame()\r\ndf[\'col1\'] = np.random.rand(100)\r\ndf[\'col2\'] = np.random.rand(100)\r\n\r\ndf.to_parquet(\'test.parquet\')\r\n\r\ndf = pd.read_parquet(\'test.parquet\')\r\n\r\nprint(df)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nIMPORTANT: This only happens when debugging on line: pd.read_parquet(\'test.parquet\')\r\nI am using spyder on anaconda.\r\nI can provide dependencies if necessary.\r\n\r\n<details>\r\nTraceback (most recent call last):\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\spyder_kernels\\customize\\spyderpdb.py", line 776, in run\r\n    super(SpyderPdb, self).run(cmd, globals, locals)\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\bdb.py", line 597, in run\r\n    exec(cmd, globals, locals)\r\n\r\n  File "c:\\users\\edudv\\downloads\\test.py", line 16, in <module>\r\n    df = pd.read_parquet(\'test.parquet\')\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\io\\parquet.py", line 493, in read_parquet\r\n    return impl.read(\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\io\\parquet.py", line 240, in read\r\n    result = self.api.parquet.read_table(\r\n\r\n  File "pyarrow\\array.pxi", line 767, in pyarrow.lib._PandasConvertible.to_pandas\r\n\r\n  File "pyarrow\\table.pxi", line 1996, in pyarrow.lib.Table._to_pandas\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pyarrow\\pandas_compat.py", line 788, in table_to_blockmanager\r\n    columns = _deserialize_column_index(table, all_columns, column_indexes)\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pyarrow\\pandas_compat.py", line 903, in _deserialize_column_index\r\n    columns = _flatten_single_level_multiindex(columns)\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pyarrow\\pandas_compat.py", line 1150, in _flatten_single_level_multiindex\r\n    if not index.is_unique:\r\n\r\n  File "pandas\\_libs\\properties.pyx", line 37, in pandas._libs.properties.CachedProperty.__get__\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\core\\indexes\\base.py", line 2237, in is_unique\r\n    return self._engine.is_unique\r\n\r\n  File "pandas\\_libs\\properties.pyx", line 37, in pandas._libs.properties.CachedProperty.__get__\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\core\\indexes\\multi.py", line 1097, in _engine\r\n    return MultiIndexUIntEngine(self.levels, self.codes, offsets)\r\n\r\n  File "pandas\\_libs\\index.pyx", line 635, in pandas._libs.index.BaseMultiIndexCodesEngine.__init__\r\n\r\n  File "C:\\Users\\edudv\\miniconda3\\envs\\test_pd\\lib\\site-packages\\pandas\\core\\indexes\\multi.py", line 136, in _codes_to_ints\r\n    codes <<= self.offsets\r\n\r\nAttributeError: \'MultiIndex\' object has no attribute \'offsets\'\r\n\r\n</details>\r\n\r\n### Expected Behavior\r\n\r\nRead parquet file\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 4bfe3d07b4858144c219b9346329027024102ab6\r\npython           : 3.10.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19044\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 60 Stepping 3, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en\r\nLOCALE           : es_ES.cp1252\r\n\r\npandas      ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46890/timeline',
#   'performed_via_github_app': None}]

# %%
pd.DataFrame(data1, columns=['id','url', 'repository_url', 'lables_url','user'])
# Out:
#             id                                                url  \
# 0   1225167599  https://api.github.com/repos/pandas-dev/pandas...
# 1   1224888845  https://api.github.com/repos/pandas-dev/pandas...
# 2   1224829902  https://api.github.com/repos/pandas-dev/pandas...
# 3   1224748301  https://api.github.com/repos/pandas-dev/pandas...
# 4   1224564144  https://api.github.com/repos/pandas-dev/pandas...
# 5   1224248446  https://api.github.com/repos/pandas-dev/pandas...
# 6   1223430815  https://api.github.com/repos/pandas-dev/pandas...
# 7   1223420483  https://api.github.com/repos/pandas-dev/pandas...
# 8   1223381879  https://api.github.com/repos/pandas-dev/pandas...
# 9   1223324439  https://api.github.com/repos/pandas-dev/pandas...
# 10  1222957102  https://api.github.com/repos/pandas-dev/pandas...
# 11  1222682814  https://api.github.com/repos/pandas-dev/pandas...
# 12  1222211412  https://api.github.com/repos/pandas-dev/pandas...
# 13  1222178317  https://api.github.com/repos/pandas-dev/pandas...
# 14  1222014732  https://api.github.com/repos/pandas-dev/pandas...
# 15  1221938636  https://api.github.com/repos/pandas-dev/pandas...
# 16  1221937554  https://api.github.com/repos/pandas-dev/pandas...
# 17  1221860584  https://api.github.com/repos/pandas-dev/pandas...
# 18  1221828150  https://api.github.com/repos/pandas-dev/pandas...
# 19  1221734240  https://api.github.com/repos/pandas-dev/pandas...
# 20  1221694919  https://api.github.com/repos/pandas-dev/pandas...
# 21  1221687570  https://api.github.com/repos/pandas-dev/pandas...
# 22  1221685599  https://api.github.com/repos/pandas-dev/pandas...
# 23  1221678412  https://api.github.com/repos/pandas-dev/pandas...
# 24  1221383537  https://api.github.com/repos/pandas-dev/pandas...
# 25  1219996829  https://api.github.com/repos/pandas-dev/pandas...
# 26  1219860886  https://api.github.com/repos/pandas-dev/pandas...
# 27  1219301794  https://api.github.com/repos/pandas-dev/pandas...
# 28  1218999811  https://api.github.com/repos/pandas-dev/pandas...
# 29  1218658465  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  lables_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas         NaN
# 1   https://api.github.com/repos/pandas-dev/pandas         NaN
# 2   https://api.github.com/repos/pandas-dev/pandas         NaN
# 3   https://api.github.com/repos/pandas-dev/pandas         NaN
# 4   https://api.github.com/repos/pandas-dev/pandas         NaN
# 5   https://api.github.com/repos/pandas-dev/pandas         NaN
# 6   https://api.github.com/repos/pandas-dev/pandas         NaN
# 7   https://api.github.com/repos/pandas-dev/pandas         NaN
# 8   https://api.github.com/repos/pandas-dev/pandas         NaN
# 9   https://api.github.com/repos/pandas-dev/pandas         NaN
# 10  https://api.github.com/repos/pandas-dev/pandas         NaN
# 11  https://api.github.com/repos/pandas-dev/pandas         NaN
# 12  https://api.github.com/repos/pandas-dev/pandas         NaN
# 13  https://api.github.com/repos/pandas-dev/pandas         NaN
# 14  https://api.github.com/repos/pandas-dev/pandas         NaN
# 15  https://api.github.com/repos/pandas-dev/pandas         NaN
# 16  https://api.github.com/repos/pandas-dev/pandas         NaN
# 17  https://api.github.com/repos/pandas-dev/pandas         NaN
# 18  https://api.github.com/repos/pandas-dev/pandas         NaN
# 19  https://api.github.com/repos/pandas-dev/pandas         NaN
# 20  https://api.github.com/repos/pandas-dev/pandas         NaN
# 21  https://api.github.com/repos/pandas-dev/pandas         NaN
# 22  https://api.github.com/repos/pandas-dev/pandas         NaN
# 23  https://api.github.com/repos/pandas-dev/pandas         NaN
# 24  https://api.github.com/repos/pandas-dev/pandas         NaN
# 25  https://api.github.com/repos/pandas-dev/pandas         NaN
# 26  https://api.github.com/repos/pandas-dev/pandas         NaN
# 27  https://api.github.com/repos/pandas-dev/pandas         NaN
# 28  https://api.github.com/repos/pandas-dev/pandas         NaN
# 29  https://api.github.com/repos/pandas-dev/pandas         NaN
#
#                                                  user
# 0   {'login': 'Condielj', 'id': 46547065, 'node_id...
# 1   {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 2   {'login': 'patrickmckenna', 'id': 3589536, 'no...
# 3   {'login': 'galipremsagar', 'id': 11664259, 'no...
# 4   {'login': 'wlach', 'id': 20569, 'node_id': 'MD...
# 5   {'login': 'r7butler', 'id': 40872002, 'node_id...
# 6   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 7   {'login': 'alexondor', 'id': 39064444, 'node_i...
# 8   {'login': 'iasoon', 'id': 6320308, 'node_id': ...
# 9   {'login': 'iasoon', 'id': 6320308, 'node_id': ...
# 10  {'login': 'yoch', 'id': 795960, 'node_id': 'MD...
# 11  {'login': 'brenojesusfernandes', 'id': 3220368...
# 12  {'login': 'iasoon', 'id': 6320308, 'node_id': ...
# 13  {'login': 'nilslacroix', 'id': 56065345, 'node...
# 14  {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 15  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 16  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 17  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 18  {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 19  {'login': 'provinzio', 'id': 20270870, 'node_i...
# 20  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 21  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 22  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 23  {'login': 'Yikun', 'id': 1736354, 'node_id': '...
# 24  {'login': 'rubenvdg', 'id': 37443208, 'node_id...
# 25  {'login': 'ppinkhasov', 'id': 6701857, 'node_i...
# 26  {'login': 'ahawryluk', 'id': 50434302, 'node_i...
# 27  {'login': 'xr-chen', 'id': 56777910, 'node_id'...
# 28  {'login': 'ericbmoreira', 'id': 58861041, 'nod...
# 29  {'login': 'eddaz7', 'id': 59227306, 'node_id':...

# %%
ab = pd.DataFrame(data1,columns=['id','url', 'repository_url', 'lables_url','user'])

# %%
ab.to_csv('json_res.csv')
