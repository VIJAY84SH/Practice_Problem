# %%
import pandas as pd
import numpy as np

# %%
cr = pd.read_csv('CreditRisk.csv')

# %%
cr
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002   Male      No         0.0      Graduate            No
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
cr.isnull().sum()
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cr.Gender.value_counts()
# Out:
# Male      775
# Female    182
# Name: Gender, dtype: int64

# %%
cr.Gender.fillna('Male',inplace = True)   # null value is filled by male

# %%
cr.Gender.isnull().sum()   #after fillining null value, null became zero
# Out:
# 0

# %%
cr.Gender.fillna('Male',inplace=True)

# %%
cr.Gender.isnull().sum()
# Out:
# 0

# %%
cr.Married.fillna('No',inplace=True)

# %%
cr.Dependents.value_counts()
# Out:
# 0.0    545
# 1.0    160
# 2.0    160
# 4.0     90
# 3.0      1
# Name: Dependents, dtype: int64

# %%
cr.Dependents.fillna(0.0,inplace =True)

# %%
cr.Self_Employed.value_counts()
# Out:
# No     807
# Yes    119
# Name: Self_Employed, dtype: int64

# %%
cr.Self_Employed.fillna('No',inplace=True)

# %%
cr.LoanAmount.value_counts()
# Out:
# 120.0    29
# 110.0    27
# 100.0    24
# 187.0    21
# 150.0    19
#          ..
# 218.0     1
# 62.0      1
# 53.0      1
# 242.0     1
# 197.0     1
# Name: LoanAmount, Length: 232, dtype: int64

# %%
cr.LoanAmount.fillna(cr.LoanAmount.mean(),inplace=True)

# %%
cr.LoanAmount.isnull().sum()
# Out:
# 0

# %%
cr.LoanAmount.mean()
# Out:
# 142.51153039832283

# %%
cr.LoanAmount.value_counts()
# Out:
# 120.00000    29
# 142.51153    27
# 110.00000    27
# 100.00000    24
# 187.00000    21
#              ..
# 218.00000     1
# 62.00000      1
# 53.00000      1
# 242.00000     1
# 197.00000     1
# Name: LoanAmount, Length: 233, dtype: int64

# %%
cr.Loan_Amount_Term.value_counts()
# Out:
# 360.0    823
# 180.0     66
# 480.0     23
# 300.0     20
# 240.0      8
# 84.0       7
# 120.0      4
# 60.0       3
# 36.0       3
# 12.0       2
# 350.0      1
# 6.0        1
# Name: Loan_Amount_Term, dtype: int64

# %%
cr.Loan_Amount_Term.fillna(cr.Loan_Amount_Term.mean(),inplace = True)

# %%
cr.Credit_History.value_counts()
# Out:
# 1.0    754
# 0.0    148
# Name: Credit_History, dtype: int64

# %%
cr.Credit_History.fillna(0.0,inplace=True)

# %%
cr.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0   142.51153             360.0
# 1             4583             1508.0   128.00000             360.0
# 2             3000                0.0    66.00000             360.0
# 3             2583             2358.0   120.00000             360.0
# 4             6000                0.0   141.00000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.drop('Loan_ID',axis =1,inplace=True)

# %%
cr.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No         0.0      Graduate            No             5849
# 1   Male     Yes         1.0      Graduate            No             4583
# 2   Male     Yes         0.0      Graduate           Yes             3000
# 3   Male     Yes         0.0  Not Graduate            No             2583
# 4   Male      No         0.0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0   142.51153             360.0             1.0
# 1             1508.0   128.00000             360.0             1.0
# 2                0.0    66.00000             360.0             1.0
# 3             2358.0   120.00000             360.0             1.0
# 4                0.0   141.00000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
cr.Gender =le.fit_transform(cr.Gender)

# %%
cr.head()
# Out:
#    Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0       1      No         0.0      Graduate            No             5849
# 1       1     Yes         1.0      Graduate            No             4583
# 2       1     Yes         0.0      Graduate           Yes             3000
# 3       1     Yes         0.0  Not Graduate            No             2583
# 4       1      No         0.0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0   142.51153             360.0             1.0
# 1             1508.0   128.00000             360.0             1.0
# 2                0.0    66.00000             360.0             1.0
# 3             2358.0   120.00000             360.0             1.0
# 4                0.0   141.00000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# ...

# %%
cr.select_dtypes(include='object').columns
# Out:
# Index(['Married', 'Education', 'Self_Employed', 'Property_Area',
#        'Loan_Status'],
#       dtype='object')

# %%
cr[cr.select_dtypes(include='object').columns] = cr[cr.select_dtypes(include='object').columns].apply(le.fit_transform)

# %%
cr.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0         0.0          0              0             5849
# 1       1        1         1.0          0              0             4583
# 2       1        1         0.0          0              1             3000
# 3       1        1         0.0          1              0             2583
# 4       1        0         0.0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0   142.51153             360.0             1.0
# 1             1508.0   128.00000             360.0             1.0
# 2                0.0    66.00000             360.0             1.0
# 3             2358.0   120.00000             360.0             1.0
# 4                0.0   141.00000             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_cr,test_cr = train_test_split(cr,test_size=0.2)

# %%
cr.shape
# Out:
# (981, 12)

# %%
train_cr.shape
# Out:
# (784, 12)

# %%
test_cr.shape
# Out:
# (197, 12)

# %%
train_cr_x =train_cr.iloc[: ,:-1]
train_cr_y = train_cr.iloc[:,-1]

# %%
test_cr_x = test_cr.iloc[ : , :-1]
test_cr_y = test_cr.iloc[: ,-1]

# %%
train_cr_x.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 206       0        0         0.0          0              0             3244
# 473       0        0         0.0          0              1             2500
# 366       1        0         0.0          0              0             2500
# 764       1        0         0.0          0              0             3071
# 66        1        0         0.0          1              0             3200
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 206                0.0        80.0             360.0             1.0
# 473                0.0        93.0             360.0             0.0
# 366                0.0        96.0             480.0             1.0
# 764             4309.0       180.0             360.0             1.0
# 66              2254.0       126.0             180.0             0.0
#
#      Property_Area
# 206              2
# 473              2
# 366              1
# ...

# %%
train_cr_y
# Out:
# 206    1
# 473    1
# 366    0
# 764    1
# 66     0
#       ..
# 461    1
# 693    1
# 30     0
# 671    1
# 474    1
# Name: Loan_Status, Length: 784, dtype: int32

# %%
test_cr_x.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 197       0        0         0.0          1              0             1907
# 40        1        0         0.0          0              0             3600
# 249       1        1         0.0          0              0             1809
# 82        0        1         2.0          0              0             1378
# 916       0        0         0.0          0              1            14987
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 197             2365.0       120.0        342.201873             1.0
# 40                 0.0        80.0        360.000000             1.0
# 249             1868.0        90.0        360.000000             1.0
# 82              1881.0       167.0        360.000000             1.0
# 916                0.0       177.0        360.000000             1.0
#
#      Property_Area
# 197              2
# 40               2
# 249              2
# ...

# %%
test_cr_y
# Out:
# 197    1
# 40     0
# 249    1
# 82     0
# 916    1
#       ..
# 263    1
# 266    1
# 386    1
# 135    0
# 850    0
# Name: Loan_Status, Length: 197, dtype: int32

# %%
cr = pd.read_csv('CreditRisk.csv')

# %%
cr.loc[ : ,['Gender','Married','Education','LoanAmount','Credit_History','Loan_Status']]
# Out:
#     Gender Married     Education  LoanAmount  Credit_History Loan_Status
# 0     Male      No      Graduate         NaN             1.0           Y
# 1     Male     Yes      Graduate       128.0             1.0           N
# 2     Male     Yes      Graduate        66.0             1.0           Y
# 3     Male     Yes  Not Graduate       120.0             1.0           Y
# 4     Male      No      Graduate       141.0             1.0           Y
# ..     ...     ...           ...         ...             ...         ...
# 976   Male     Yes  Not Graduate       113.0             1.0           Y
# 977   Male     Yes      Graduate       115.0             1.0           Y
# 978   Male      No      Graduate       126.0             NaN           Y
# 979   Male     Yes      Graduate       158.0             1.0           N
# 980   Male      No      Graduate        98.0             1.0           Y
#
# [981 rows x 6 columns]

# %%
cr[cr['Loan_Status'] == 'Y']
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002   Male      No         0.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# 5    LP001011   Male     Yes         2.0      Graduate           Yes
# ..        ...    ...     ...         ...           ...           ...
# 975  LP002969   Male     Yes         1.0      Graduate            No
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df = pd.DataFrame(cr.loc[:,'Loan_Status'] == 'Y')

# %%
cr.loc[:,'Loan_Status'] == 'Y'
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 976     True
# 977     True
# 978     True
# 979    False
# 980     True
# Name: Loan_Status, Length: 981, dtype: bool

# %%
pd.DataFrame(cr[cr["Loan_Status"]=='Y'].Loan_Status)
# Out:
#     Loan_Status
# 0             Y
# 2             Y
# 3             Y
# 4             Y
# 5             Y
# ..          ...
# 975           Y
# 976           Y
# 977           Y
# 978           Y
# 980           Y
#
# [712 rows x 1 columns]

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr['New_Income'] = cr['Education'] == 'Graduate'

# %%
cr.loc[cr["Education"] == "Graduate","New_Income"] = cr["ApplicantIncome"]+1000

# %%
cr.loc[cr['Education'] == 'Not Graduate',"New_Income"] =cr["ApplicantIncome"]+500

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status New_Income
# 0             1.0         Urban           Y       6849
# ...

# %%
cr['New_Income1'] = cr['New_Income']

# %%
cr.head(3)
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 0  LP001002   Male      No         0.0  Graduate            No
# 1  LP001003   Male     Yes         1.0  Graduate            No
# 2  LP001005   Male     Yes         0.0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status New_Income New_Income1
# 0             1.0         Urban           Y       6849        6849
# 1             1.0         Rural           N       5583        5583
# 2             1.0         Urban           Y       4000        4000

# %%
cr.loc[cr["Self_Employed"]=='No','New_Income1']='No'

# %%
cr.loc[cr["Self_Employed"]=='Yes','New_Income1']='Yes'

# %%
cr.rename(columns={'New_Income1':'Employee_Status'},inplace=True)

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status New_Income Employee_Status
# 0             1.0         Urban           Y       6849              No
# ...

# %%
a = list(cr.columns)

# %%
a
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status',
#  'New_Income',
#  'Employee_Status']

# %%
cr[a[0:6]+[a[-1]]+a[6:-1]]  # arranging columns
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002   Male      No         0.0      Graduate            No
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#     Employee_Status  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0                No             5849                0.0         NaN
# ...

# %%
cr.groupby('Gender').ApplicantIncome.sum()
# Out:
# Gender
# Female     811521
# Male      4074117
# Name: ApplicantIncome, dtype: int64

# %%
cr.groupby("Gender")['ApplicantIncome'].mean()
# Out:
# Gender
# Female    4458.906593
# Male      5256.925161
# Name: ApplicantIncome, dtype: float64

# %%
cr.sort_values(['ApplicantIncome','New_Income'],ascending=[1,0]).groupby('Property_Area').mean()
# Out:
#                Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Property_Area
# Rural            0.839721      5178.924138        1752.607310  146.787986
# Semiurban        0.884615      5110.593123        1503.939828  141.684211
# Urban            0.915408      5251.152047        1574.119298  139.693009
#
#                Loan_Amount_Term  Credit_History
# Property_Area
# Rural                344.204225        0.820896
# Semiurban            345.095652        0.841615
# Urban                337.481928        0.842949

# %%
cr.groupby(['Property_Area']).mean().sort_values(['ApplicantIncome','New_Income'],ascending=[1,0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3716\2487205207.py in <module>
# ----> 1 cr.groupby(['Property_Area']).mean().sort_values(['ApplicantIncome','New_Income'],ascending=[1,0])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6302         if len(by) > 1:
#    6303
# -> 6304             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6305
#    6306             # need to rewrap columns in Series to apply key function
#
# ...

# %%
cr.groupby(['Property_Area']).sum()

# %%
cr.corr()

# %%
cr.head()

# %%
names = list(cr.columns)

# %%
names

# %%
names.remove('Dependents')

# %%
names

# %%
corr_list=[]
for i in names:
    corr_list.append(cr.Dependents.corr(cr[i]))

# %%
d2 = cr.corr().iloc[:,0].reset_index()

# %%
d2.drop([0],inplace=True)

# %%
d2

# %%
d = cr[['Dependents','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','New_Income']]

# %%
d

# %%
name = list(d.columns)
name.remove("Dependents")
name

# %%
corr_l = []
for i in name:
    corr_l.append(d.Dependents.corr(d[i]))

# %%
corr_df = pd.DataFrame({"col_Names":name,"co_relation":corr_l})

# %%
corr_df

# %%
corr_l.append(cr.Dependents.corr(d[i]))

# %% [markdown]
# ### CHI_Square Test

# %%
a = pd.crosstab(cr.ApplicantIncome,cr.Credit_History)

# %%
a

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(a)

# %%
from scipy.stats import f_oneway

# %%
f_oneway(cr[cr.Education == "Graduate"].ApplicantIncome,cr[cr.Education == "Not Graduate"].ApplicantIncome)

# %%
f_oneway(cr[cr.Gender == 'Male'].ApplicantIncome,cr[cr.Gender=='Female'].ApplicantIncome)

# %%
l1 = [12,23,34,45,56]
l2 = [87,65,44,34,32]

# %%
df = pd.DataFrame({'L1':l1,'L2':l2})

# %%
df

# %%
df.corr()

# %%
l = [1,2,3,4]
l1 =[4,3,2,1]

df = pd.DataFrame({"L1":l,"L2":l1})

# %%
df

# %%
df.corr()  # Negative Correlation

# %%
l = ["oneWay","pratik","salUnkhe","vijay","Patil"]
for i in l:
