# %%
import pandas as pd
import numpy as np

# %%
#import warnings
#warnings.filterwarnings('ignore')

# %%
s1 = ["vijay","patil","pratik","salunkhe","ram"]

# %%
df1 = pd.DataFrame(s1)

# %%
df1
# Out:
#           0
# 0     vijay
# 1     patil
# 2    pratik
# 3  salunkhe
# 4       ram

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
# dtypes: object(1)
# memory usage: 168.0+ bytes

# %%
s2 = ["vijay","patil","pratik","ram",[1,2,3]]

# %%
df2 = pd.DataFrame(s2)

# %%
df2
# Out:
#            0
# 0      vijay
# 1      patil
# 2     pratik
# 3        ram
# 4  [1, 2, 3]

# %%
store_list = [['vivo',30000],['oppo',25000],['mi',21000]]

# %%
df3 = pd.DataFrame(store_list,columns = ['store','Sales'])

# %%
df3
# Out:
#   store  Sales
# 0  vivo  30000
# 1  oppo  25000
# 2    mi  21000

# %%
store_data= {'name': ["vijay","pratik","ram","akash"],
             'Home_town': ["kolhapur","satara","hingoli","nagapur"]}

# %%
df4 = pd.DataFrame(store_data)

# %%
df4
# Out:
#      name Home_town
# 0   vijay  kolhapur
# 1  pratik    satara
# 2     ram   hingoli
# 3   akash   nagapur

# %%
df4.sort_values(by='Home_town',ascending= False,inplace=True) # inplace True change original dataframe

# %%
df4
# Out:
#      name Home_town
# 1  pratik    satara
# 3   akash   nagapur
# 0   vijay  kolhapur
# 2     ram   hingoli

# %% [markdown]
# ### Sorting Columns ---> Give axis =1

# %%
df4
# Out:
#      name Home_town
# 1  pratik    satara
# 3   akash   nagapur
# 0   vijay  kolhapur
# 2     ram   hingoli

# %%
df4.sort_index(axis = 0)
# Out:
#      name Home_town
# 0   vijay  kolhapur
# 1  pratik    satara
# 2     ram   hingoli
# 3   akash   nagapur

# %%
df4.sort_index(axis = 1)
# Out:
#   Home_town    name
# 1    satara  pratik
# 3   nagapur   akash
# 0  kolhapur   vijay
# 2   hingoli     ram

# %%
df4.sort_index(axis = 0, ascending=False)
# Out:
#      name Home_town
# 3   akash   nagapur
# 2     ram   hingoli
# 1  pratik    satara
# 0   vijay  kolhapur

# %%
sd= {'name': ["vijay","pratik","ram","akash","Rupesh"],
             'Home_town': ["kolhapur","satara","hingoli","nagapur",None]}

# %% [markdown]
# ### Custom_index

# %%
df5 = pd.DataFrame(sd,index = ['a','b','c','d','e'])

# %%
df5
# Out:
#      name Home_town
# a   vijay  kolhapur
# b  pratik    satara
# c     ram   hingoli
# d   akash   nagapur
# e  Rupesh      None

# %%
df5.sort_values(by = 'Home_town',na_position='first')
# Out:
#      name Home_town
# e  Rupesh      None
# c     ram   hingoli
# a   vijay  kolhapur
# d   akash   nagapur
# b  pratik    satara

# %%
sd1 = [{'store_A':110,'store_B':120},{'store_A':145,'store_B':150,'store_C':184}]

# %%
df6 = pd.DataFrame(sd1)

# %%
df6
# Out:
#    store_A  store_B  store_C
# 0      110      120      NaN
# 1      145      150    184.0

# %% [markdown]
# ### Types of columns  and rows in Dataframe

# %%
df3
# Out:
#   store  Sales
# 0  vivo  30000
# 1  oppo  25000
# 2    mi  21000

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df3['store'])
# Out:
# pandas.core.series.Series

# %%
type(df3['Sales'])
# Out:
# pandas.core.series.Series

# %%
type(df3.iloc[0])    # type of 0th row in dataframe
# Out:
# pandas.core.series.Series

# %%
df3.iloc[0]
# Out:
# store     vivo
# Sales    30000
# Name: 0, dtype: object

# %%
df3.iloc[1]
# Out:
# store     oppo
# Sales    25000
# Name: 1, dtype: object

# %% [markdown]
# ### Reading data from various

# %%
data1 =pd.read_csv('Bank_branch_PL.csv')

# %%
data1
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data2 = pd.read_csv(r'E:\mysql\SQL_CLASS_EXERCISE\Dataset\Bank_branch_PL.csv')

# %%
data2
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data1.head()
# Out:
#   Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0  Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1  Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2  Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3  Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4    Hyd   99101   SmartSav  66660070  79090090          10050077      3

# %%
data1.tail()
# Out:
#     Branch  Banker   Product      Cost   revenue  Estimated_profit  month
# 7      Hyd   77301  SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201  BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201  BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201  SmartSav  40054070  60070080          20050070      2
# 11  Banglr   99101  SmartSav  88660070  79090090          10050077      3

# %%
data1.info
# Out:
# <bound method DataFrame.info of     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %% [markdown]
# ### Zip_File

# %%
import zipfile

# %%
with zipfile.ZipFile('Bank_branch_PL.zip') as z:
    with z.open('Bank_branch_PL.csv') as f:
        data3 = pd.read_csv(f)

# %%
data3
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
with zipfile.ZipFile('E:\mysql\SQL_CLASS_EXERCISE\Bank_branch_PL.zip') as z:
    with z.open('Bank_branch_PL.csv') as f:
        data3_z = pd.read_csv(f)

# %%
data3_z
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data4 = pd.read_csv('Bank_branch_PL.txt')

# %%
data4
# Out:
#    Branch\tBanker\tProduct\tCost\trevenue\tEstimated_profit\tmonth
# 0   Delhi\t99101\tSuperSave\t30060070\t50060070\t2...
# 1   Delhi\t99101\tSuperSave\t30060070\t50060070\t2...
# 2   Delhi\t99101\tSmartSav\t45060070\t57060070\t30...
# 3   Delhi\t99101\tEasyCash\t66660070\t50090090\t10...
# 4   Hyd\t99101\tSmartSav\t66660070\t79090090\t1005...
# 5   Banglr\t77301\tEasyCash\t55560070\t61090090\t9...
# 6   Banglr\t77301\tSmartSav\t54460090\t53090080\t1...
# 7   Hyd\t77301\tSmartSav\t53060090\t63090080\t2995...
# 8   Hyd\t88201\tBusiCard\t40030070\t60070080\t1005...
# 9   Hyd\t88201\tBusiCard\t70030070\t60070080\t2506...
# 10  Hyd\t88201\tSmartSav\t40054070\t60070080\t2005...
# 11  Banglr\t99101\tSmartSav\t88660070\t79090090\t1...

# %%
data4_a = pd.read_csv('Bank_branch_PL.txt',sep = '\t')

# %%
data4_a
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data1.head(10)
# Out:
#    Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0   Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1   Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2   Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3   Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4     Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5  Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6  Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7     Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8     Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9     Hyd   88201   BusiCard  70030070  60070080          25060070      1

# %% [markdown]
# ### Data Exploration

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Branch            12 non-null     object
#  1   Banker            12 non-null     int64
#  2   Product           12 non-null     object
#  3   Cost              12 non-null     int64
#  4   revenue           12 non-null     int64
#  5   Estimated_profit  12 non-null     int64
#  6   month             12 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 800.0+ bytes

# %%
data1.describe()   # detailed stastical information about numerical column in data
# Out:
#              Banker          Cost       revenue  Estimated_profit      month
# count     12.000000  1.200000e+01  1.200000e+01      1.200000e+01  12.000000
# mean   90926.000000  5.336291e+07  6.024425e+07      1.794257e+07   2.166667
# std     9439.676901  1.756367e+07  9.959462e+06      7.815086e+06   0.937437
# min    77301.000000  3.006007e+07  5.006007e+07      9.950077e+06   1.000000
# 25%    85476.000000  4.004807e+07  5.234008e+07      1.005008e+07   1.000000
# 50%    93651.000000  5.376009e+07  6.007008e+07      2.000007e+07   2.500000
# 75%    99101.000000  6.666007e+07  6.159009e+07      2.130257e+07   3.000000
# max    99101.000000  8.866007e+07  7.909009e+07      3.005007e+07   3.000000

# %%
round(data1.describe(),1)
# Out:
#         Banker        Cost     revenue  Estimated_profit  month
# count     12.0        12.0        12.0              12.0   12.0
# mean   90926.0  53362906.7  60244247.5        17942573.5    2.2
# std     9439.7  17563669.6   9959462.1         7815085.5    0.9
# min    77301.0  30060070.0  50060070.0         9950077.0    1.0
# 25%    85476.0  40048070.0  52340082.5        10050077.0    1.0
# 50%    93651.0  53760090.0  60070080.0        20000073.5    2.5
# 75%    99101.0  66660070.0  61590087.5        21302570.0    3.0
# max    99101.0  88660070.0  79090090.0        30050070.0    3.0

# %%
data1.shape      # rows and column count
# Out:
# (12, 7)

# %%
data1.shape[0]  # row
# Out:
# 12

# %%
data1.shape[1]    # column
# Out:
# 7

# %%
data1.dtypes
# Out:
# Branch              object
# Banker               int64
# Product             object
# Cost                 int64
# revenue              int64
# Estimated_profit     int64
# month                int64
# dtype: object

# %%
len(data1)    # count of rows
# Out:
# 12

# %%
data1.columns   # all columns in data
# Out:
# Index(['Branch', 'Banker', 'Product', 'Cost', 'revenue', 'Estimated_profit',
#        'month'],
#       dtype='object')

# %%
len(data1.columns)    # count of columns in  data
# Out:
# 7

# %%
sorted(data1.columns)
# Out:
# ['Banker', 'Branch', 'Cost', 'Estimated_profit', 'Product', 'month', 'revenue']

# %%
import pathlib
import zipfile
import os

directory = pathlib.Path('f1')

# """with zipfile.ZipFile(r'C:\Users\MR.GODHADE\Desktop\Python\f1.zip') as archive:
#     archive.printdir()"""
    
for file_path in directory.rglob("*"):
    data_4 = pd.read_csv(file_path)
    print(file_path)

# %%
data_4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10288\3691932332.py in <module>
# ----> 1 data_4
#
# NameError: name 'data_4' is not defined

# %% [markdown]
# ### Indexing and Slicing

# %%
data1
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data1.iloc[0]
# Out:
# Branch                  Delhi
# Banker                  99101
# Product             SuperSave
# Cost                 30060070
# revenue              50060070
# Estimated_profit     20050070
# month                       1
# Name: 0, dtype: object

# %%
data1.iloc[2,2]
# Out:
# 'SmartSav'

# %%
data1.iloc[0,0]
# Out:
# 'Delhi'

# %%
data1.head(3)
# Out:
#   Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0  Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1  Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2  Delhi   99101   SmartSav  45060070  57060070          30050070      2

# %% [markdown]
# ### Slicing

# %%
data1.iloc[::]
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data1.iloc[:,0:4]
# Out:
#     Branch  Banker    Product      Cost
# 0    Delhi   99101  SuperSave  30060070
# 1    Delhi   99101  SuperSave  30060070
# 2    Delhi   99101   SmartSav  45060070
# 3    Delhi   99101   EasyCash  66660070
# 4      Hyd   99101   SmartSav  66660070
# 5   Banglr   77301   EasyCash  55560070
# 6   Banglr   77301   SmartSav  54460090
# 7      Hyd   77301   SmartSav  53060090
# 8      Hyd   88201   BusiCard  40030070
# 9      Hyd   88201   BusiCard  70030070
# 10     Hyd   88201   SmartSav  40054070
# 11  Banglr   99101   SmartSav  88660070

# %%
data1.iloc[0:3,0:4]
# Out:
#   Branch  Banker    Product      Cost
# 0  Delhi   99101  SuperSave  30060070
# 1  Delhi   99101  SuperSave  30060070
# 2  Delhi   99101   SmartSav  45060070

# %%
data1.loc[0:5,["Cost","month"]]
# Out:
#        Cost  month
# 0  30060070      1
# 1  30060070      1
# 2  45060070      2
# 3  66660070      3
# 4  66660070      3
# 5  55560070      3

# %%
data1.loc[0:5,["Product","Cost"]]
# Out:
#      Product      Cost
# 0  SuperSave  30060070
# 1  SuperSave  30060070
# 2   SmartSav  45060070
# 3   EasyCash  66660070
# 4   SmartSav  66660070
# 5   EasyCash  55560070

# %% [markdown]
# ### Filtering Dataframe

# %%
data1["Cost"]  # Accessing column
# Out:
# 0     30060070
# 1     30060070
# 2     45060070
# 3     66660070
# 4     66660070
# 5     55560070
# 6     54460090
# 7     53060090
# 8     40030070
# 9     70030070
# 10    40054070
# 11    88660070
# Name: Cost, dtype: int64

# %%
data1.Cost # accesing column
# Out:
# 0     30060070
# 1     30060070
# 2     45060070
# 3     66660070
# 4     66660070
# 5     55560070
# 6     54460090
# 7     53060090
# 8     40030070
# 9     70030070
# 10    40054070
# 11    88660070
# Name: Cost, dtype: int64

# %%
data1[data1['Cost']>70000000]
# Out:
#     Branch  Banker   Product      Cost   revenue  Estimated_profit  month
# 9      Hyd   88201  BusiCard  70030070  60070080          25060070      1
# 11  Banglr   99101  SmartSav  88660070  79090090          10050077      3

# %%
data1
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data1[data1['month'] >2]
# Out:
#     Branch  Banker   Product      Cost   revenue  Estimated_profit  month
# 3    Delhi   99101  EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101  SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301  EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301  SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301  SmartSav  53060090  63090080          29950077      3
# 11  Banglr   99101  SmartSav  88660070  79090090          10050077      3

# %%
data1[(data1['month']>2) & (data1['Cost'] > 600000)]
# Out:
#     Branch  Banker   Product      Cost   revenue  Estimated_profit  month
# 3    Delhi   99101  EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101  SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301  EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301  SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301  SmartSav  53060090  63090080          29950077      3
# 11  Banglr   99101  SmartSav  88660070  79090090          10050077      3

# %%
data1.to_csv('vijay.csv')

# %% [markdown]
# ### Sorting

# %%
data1.sort_index(ascending=False)
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 11  Banglr   99101   SmartSav  88660070  79090090          10050077      3
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# ...

# %%
data1.sort_values('Cost')
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# ...

# %%
data1.sort_values('Cost',ascending=False)
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 11  Banglr   99101   SmartSav  88660070  79090090          10050077      3
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# ...

# %%
data1.sort_values('month')
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# ...

# %%
data1.sort_values(['Cost','Product'])
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# ...

# %%
data1.sort_values(['Cost','Product'],ascending=False)
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 11  Banglr   99101   SmartSav  88660070  79090090          10050077      3
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# ...

# %%
data1[data1['Banker']>80000].sort_values('revenue')
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 11  Banglr   99101   SmartSav  88660070  79090090          10050077      3

# %%
data1.sort_values(['Product','Cost'],ascending=[True,False])
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 11  Banglr   99101   SmartSav  88660070  79090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# ...

# %% [markdown]
# ### Ranking

# %%
data1['Cost'].rank(method = 'first')
# Out:
# 0      1.0
# 1      2.0
# 2      5.0
# 3      9.0
# 4     10.0
# 5      8.0
# 6      7.0
# 7      6.0
# 8      3.0
# 9     11.0
# 10     4.0
# 11    12.0
# Name: Cost, dtype: float64

# %%
data1['Costing_rank'] = data1['Cost'].rank(method = 'first')

# %%
data1[['Cost','Costing_rank']]
# Out:
#         Cost  Costing_rank
# 0   30060070           1.0
# 1   30060070           2.0
# 2   45060070           5.0
# 3   66660070           9.0
# 4   66660070          10.0
# 5   55560070           8.0
# 6   54460090           7.0
# 7   53060090           6.0
# 8   40030070           3.0
# 9   70030070          11.0
# 10  40054070           4.0
# 11  88660070          12.0

# %%
data1
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month  \
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data2
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data1['New_col1'] = 'abcd'

# %%
data1.head(5)
# Out:
#   Branch  Banker    Product      Cost   revenue  Estimated_profit  month  \
# 0  Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1  Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2  Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3  Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4    Hyd   99101   SmartSav  66660070  79090090          10050077      3
#
#    Costing_rank New_col1
# 0           1.0     abcd
# 1           2.0     abcd
# 2           5.0     abcd
# 3           9.0     abcd
# 4          10.0     abcd

# %%
data1['col2'] = data1['revenue'] - data1['Cost']
data1['col3'] = data1['revenue'] + data1['Cost']
data1['col4'] = data1['revenue'] * data1['Cost']
data1['col5'] = data1['revenue'] / data1['Cost']

# %%
data1
# Out:
#     Branch  Banker    Product      Cost   revenue  Estimated_profit  month  \
# 0    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 1    Delhi   99101  SuperSave  30060070  50060070          20050070      1
# 2    Delhi   99101   SmartSav  45060070  57060070          30050070      2
# 3    Delhi   99101   EasyCash  66660070  50090090          10050077      3
# 4      Hyd   99101   SmartSav  66660070  79090090          10050077      3
# 5   Banglr   77301   EasyCash  55560070  61090090           9950077      3
# 6   Banglr   77301   SmartSav  54460090  53090080          19950077      3
# 7      Hyd   77301   SmartSav  53060090  63090080          29950077      3
# 8      Hyd   88201   BusiCard  40030070  60070080          10050070      1
# 9      Hyd   88201   BusiCard  70030070  60070080          25060070      1
# 10     Hyd   88201   SmartSav  40054070  60070080          20050070      2
# ...

# %%
data1.insert(5,'col','vjy')   # add col at your location

# %%
data1
# Out:
#     Branch  Banker    Product      Cost   revenue  col  Estimated_profit  \
# 0    Delhi   99101  SuperSave  30060070  50060070  vjy          20050070
# 1    Delhi   99101  SuperSave  30060070  50060070  vjy          20050070
# 2    Delhi   99101   SmartSav  45060070  57060070  vjy          30050070
# 3    Delhi   99101   EasyCash  66660070  50090090  vjy          10050077
# 4      Hyd   99101   SmartSav  66660070  79090090  vjy          10050077
# 5   Banglr   77301   EasyCash  55560070  61090090  vjy           9950077
# 6   Banglr   77301   SmartSav  54460090  53090080  vjy          19950077
# 7      Hyd   77301   SmartSav  53060090  63090080  vjy          29950077
# 8      Hyd   88201   BusiCard  40030070  60070080  vjy          10050070
# 9      Hyd   88201   BusiCard  70030070  60070080  vjy          25060070
# 10     Hyd   88201   SmartSav  40054070  60070080  vjy          20050070
# 11  Banglr   99101   SmartSav  88660070  79090090  vjy          10050077
#
# ...

# %%
data1.sort_index(axis = 1,inplace = True)

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %% [markdown]
# ### Rearrange the columns

# %%
data5 = data1[['col3','col3','col4']]

# %%
data5
# Out:
#          col3       col3              col4
# 0    80120140   80120140  1504809208404900
# 1    80120140   80120140  1504809208404900
# 2   102120140  102120140  2571130748404900
# 3   116750160  116750160  3339008905706300
# 4   145750160  145750160  5272150935706300
# 5   116650160  116650160  3394169676706300
# 6   107550170  107550170  2891290534907200
# 7   116150170  116150170  3347565322907200
# 8   100100150  100100150  2404609507305600
# 9   130100150  130100150  4206711907305600
# 10  100124150  100124150  2406051189225600
# 11  167750160  167750160  7012132915706300

# %% [markdown]
# ### column Deletion

# %%
data1.drop(columns =['col2','col3'],inplace = True)

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
del data1['col']

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %% [markdown]
# ### Unique Values in column

# %%
data1['Branch'].unique()
# Out:
# array(['Delhi', 'Hyd', 'Banglr'], dtype=object)

# %%
data1['Product'].unique()
# Out:
# array(['SuperSave', 'SmartSav', 'EasyCash', 'BusiCard'], dtype=object)

# %% [markdown]
# ### if/Vlookup

# %%
data1['Branch_code'] = 0

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
data1.loc[data1['Branch'] == 'Delhi','Branch_code']=1

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
data1.loc[data1['Branch'] == 'Banglr','Branch_code']=2
data1.loc[data1['Branch'] == 'Hyd','Branch_code']=3

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
data1['Cost_value'] = 0

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
data1.loc[data1['Cost']>40000000,'Cost_value']='High_Cost'

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
data1.loc[data1['Cost']<40000000,'Cost_value']='low_Cost'

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
Branch_Code_n_Cost_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10288\1026365736.py in <module>
# ----> 1 Branch_Code_n_Cost_value
#
# NameError: name 'Branch_Code_n_Cost_value' is not defined

# %%
data1.loc[(data1['Branch'] == 'Delhi') & (data1['Branch_code']==1),'Branch_cost_value']= data1['Branch_code'].astype(str) + data1['Cost_value']

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
data1.loc[(data1['Branch'] == 'Hyd') &(data1['Branch_code'] == 3), 'Branch_cost_value']= data1['Branch_code'].astype(str)+ data1['Cost_value']

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %%
data1.loc[(data1[''])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### Summerize  Group by/Pivot table

# %% [markdown]
# #### Method 1

# %%
data1.pivot_table(index = 'Branch',values = 'revenue',aggfunc = np.sum)
# Out:
#           revenue
# Branch
# Banglr  193270260
# Delhi   207270300
# Hyd     322390410

# %% [markdown]
# #### Method 2

# %%
pd.pivot_table(data = data1,
              index = 'Branch',
              values = 'revenue',
              aggfunc = np.sum)
# Out:
#           revenue
# Branch
# Banglr  193270260
# Delhi   207270300
# Hyd     322390410

# %% [markdown]
# ### Add column to pivot Table :

# %%
data1.pivot_table(index = 'Branch',columns = 'Product',values = 'revenue',aggfunc = np.sum)
# Out:
# Product     BusiCard    EasyCash     SmartSav    SuperSave
# Branch
# Banglr           NaN  61090090.0  132180170.0          NaN
# Delhi            NaN  50090090.0   57060070.0  100120140.0
# Hyd      120140160.0         NaN  202250250.0          NaN

# %%
data1.pivot_table(index = 'Branch',columns = 'Product',values = 'revenue',aggfunc = np.sum,fill_value=0)
# Out:
# Product   BusiCard  EasyCash   SmartSav  SuperSave
# Branch
# Banglr           0  61090090  132180170          0
# Delhi            0  50090090   57060070  100120140
# Hyd      120140160         0  202250250          0

# %%
pt1 = data1.pivot_table(index = ['Branch', 'Product'],values = 'revenue',aggfunc = np.sum,fill_value=0)

# %%
pt1
# Out:
#                     revenue
# Branch Product
# Banglr EasyCash    61090090
#        SmartSav   132180170
# Delhi  EasyCash    50090090
#        SmartSav    57060070
#        SuperSave  100120140
# Hyd    BusiCard   120140160
#        SmartSav   202250250

# %%
type(pt1)
# Out:
# pandas.core.frame.DataFrame

# %%
pt1.iloc[0,0]
# Out:
# 61090090

# %%
pt1.index
# Out:
# MultiIndex([('Banglr',  'EasyCash'),
#             ('Banglr',  'SmartSav'),
#             ( 'Delhi',  'EasyCash'),
#             ( 'Delhi',  'SmartSav'),
#             ( 'Delhi', 'SuperSave'),
#             (   'Hyd',  'BusiCard'),
#             (   'Hyd',  'SmartSav')],
#            names=['Branch', 'Product'])

# %% [markdown]
# ### Flatten the pivot table

# %%
pt1.to_records()
# Out:
# rec.array([('Banglr', 'EasyCash',  61090090),
#            ('Banglr', 'SmartSav', 132180170),
#            ('Delhi', 'EasyCash',  50090090),
#            ('Delhi', 'SmartSav',  57060070),
#            ('Delhi', 'SuperSave', 100120140),
#            ('Hyd', 'BusiCard', 120140160), ('Hyd', 'SmartSav', 202250250)],
#           dtype=[('Branch', '<U6'), ('Product', '<U9'), ('revenue', '<i8')])

# %%
pt1_a = pd.DataFrame(pt1.to_records())

# %%
pt1
# Out:
#                     revenue
# Branch Product
# Banglr EasyCash    61090090
#        SmartSav   132180170
# Delhi  EasyCash    50090090
#        SmartSav    57060070
#        SuperSave  100120140
# Hyd    BusiCard   120140160
#        SmartSav   202250250

# %%
pt1_a
# Out:
#    Branch    Product    revenue
# 0  Banglr   EasyCash   61090090
# 1  Banglr   SmartSav  132180170
# 2   Delhi   EasyCash   50090090
# 3   Delhi   SmartSav   57060070
# 4   Delhi  SuperSave  100120140
# 5     Hyd   BusiCard  120140160
# 6     Hyd   SmartSav  202250250

# %%
pt2 = data1.pivot_table(index = ['Branch', 'Product'],
                        values = ['revenue','Cost'],
                        aggfunc = np.sum,
                        fill_value=0,    #filling NaN to 0
                       margins= True)    # total sum of all rows

# %%
pt2_a = pd.DataFrame(pt2.to_records())

# %%
pt2_a
# Out:
#    Branch    Product       Cost    revenue
# 0  Banglr   EasyCash   55560070   61090090
# 1  Banglr   SmartSav  143120160  132180170
# 2   Delhi   EasyCash   66660070   50090090
# 3   Delhi   SmartSav   45060070   57060070
# 4   Delhi  SuperSave   60120140  100120140
# 5     Hyd   BusiCard  110060140  120140160
# 6     Hyd   SmartSav  159774230  202250250
# 7     All             640354880  722930970

# %%
pt3 = data1.pivot_table(index = ['Branch', 'Product'],
                        values = ['revenue','Cost'],
                        aggfunc = [np.sum,'max'],
                        fill_value=0,    #filling NaN to 0
                       margins= True)

# %%
pt3_a = pd.DataFrame(pt3.to_records())

# %%
pt3_a
# Out:
#    Branch    Product  ('sum', 'Cost')  ('sum', 'revenue')  ('max', 'Cost')  \
# 0  Banglr   EasyCash         55560070            61090090         55560070
# 1  Banglr   SmartSav        143120160           132180170         88660070
# 2   Delhi   EasyCash         66660070            50090090         66660070
# 3   Delhi   SmartSav         45060070            57060070         45060070
# 4   Delhi  SuperSave         60120140           100120140         30060070
# 5     Hyd   BusiCard        110060140           120140160         70030070
# 6     Hyd   SmartSav        159774230           202250250         66660070
# 7     All                   640354880           722930970         88660070
#
#    ('max', 'revenue')
# 0            61090090
# 1            79090090
# 2            50090090
# 3            57060070
# 4            50060070
# 5            60070080
# 6            79090090
# 7            79090090

# %%
pt4 = data1.pivot_table(index = ['Branch', 'Product'],
                        values = ['revenue','Cost'],
                        aggfunc = {'revenue': np.sum,'Cost':'max'},
                        fill_value=0,    #filling NaN to 0
                       margins= True)

# %%
pt4_a = pd.DataFrame(pt4.to_records())

# %%
pt4_a
# Out:
#    Branch    Product      Cost    revenue
# 0  Banglr   EasyCash  55560070   61090090
# 1  Banglr   SmartSav  88660070  132180170
# 2   Delhi   EasyCash  66660070   50090090
# 3   Delhi   SmartSav  45060070   57060070
# 4   Delhi  SuperSave  30060070  100120140
# 5     Hyd   BusiCard  70030070  120140160
# 6     Hyd   SmartSav  66660070  202250250
# 7     All             88660070  722930970

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %% [markdown]
# ### Column Rename

# %%
data1.rename(columns = {'col4':'col4_new'})
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %% [markdown]
# ### Cross Tab

# %%
pd.pivot_table(data1,index = 'Branch',
               columns = 'revenue',
               aggfunc = 'count',
              fill_value = 0)
# Out:
#           Banker                                                        \
# revenue 50060070 50090090 53090080 57060070 60070080 61090090 63090080
# Branch
# Banglr         0        0        1        0        0        1        0
# Delhi          2        1        0        1        0        0        0
# Hyd            0        0        0        0        3        0        1
#
#                  Branch_code           ...     col5             month  \
# revenue 79090090    50060070 50090090  ... 63090080 79090090 50060070
# Branch                                 ...
# Banglr         1           0        0  ...        0        1        0
# Delhi          0           2        1  ...        0        0        2
# Hyd            1           0        0  ...        1        1        0
#
#
# revenue 50090090 53090080 57060070 60070080 61090090 63090080 79090090
# Branch
# Banglr         0        1        0        0        1        0        1
# ...

# %%
pd.crosstab(data1.Branch,data1.Cost)
# Out:
# Cost    30060070  40030070  40054070  45060070  53060090  54460090  55560070  \
# Branch
# Banglr         0         0         0         0         0         1         1
# Delhi          2         0         0         1         0         0         0
# Hyd            0         1         1         0         1         0         0
#
# Cost    66660070  70030070  88660070
# Branch
# Banglr         0         0         1
# Delhi          1         0         0
# Hyd            1         1         0

# %%
pd.crosstab(data1.Branch,data1.Cost,values = 'revenue',aggfunc = 'sum')
# Out:
# Cost          30060070 40030070 40054070 45060070 53060090 54460090 55560070  \
# Branch
# Banglr             NaN      NaN      NaN      NaN      NaN  revenue  revenue
# Delhi   revenuerevenue      NaN      NaN  revenue      NaN      NaN      NaN
# Hyd                NaN  revenue  revenue      NaN  revenue      NaN      NaN
#
# Cost   66660070 70030070 88660070
# Branch
# Banglr      NaN      NaN  revenue
# Delhi   revenue      NaN      NaN
# Hyd     revenue  revenue      NaN

# %%
data1
# Out:
#     Banker  Branch      Cost  Costing_rank  Estimated_profit New_col1  \
# 0    99101   Delhi  30060070           1.0          20050070     abcd
# 1    99101   Delhi  30060070           2.0          20050070     abcd
# 2    99101   Delhi  45060070           5.0          30050070     abcd
# 3    99101   Delhi  66660070           9.0          10050077     abcd
# 4    99101     Hyd  66660070          10.0          10050077     abcd
# 5    77301  Banglr  55560070           8.0           9950077     abcd
# 6    77301  Banglr  54460090           7.0          19950077     abcd
# 7    77301     Hyd  53060090           6.0          29950077     abcd
# 8    88201     Hyd  40030070           3.0          10050070     abcd
# 9    88201     Hyd  70030070          11.0          25060070     abcd
# 10   88201     Hyd  40054070           4.0          20050070     abcd
# 11   99101  Banglr  88660070          12.0          10050077     abcd
#
# ...

# %% [markdown]
# ### Group By

# %%
data1.groupby(by='Branch').sum()
# Out:
#         Banker       Cost  Costing_rank  Estimated_profit               col4  \
# Branch
# Banglr  253703  198680230          27.0          39950231  13297593127319800
# Delhi   396404  171840280          17.0          80200287   8919758070921000
# Hyd     441005  269834370          34.0          95160364  17637088862450300
#
#             col5  month    revenue  Branch_code
# Branch
# Banglr  2.966436      9  193270260            6
# Delhi   5.348406      7  207270300            4
# Hyd     6.233624     10  322390410           15

# %%
data1.groupby(by='Branch').count()
# Out:
#         Banker  Cost  Costing_rank  Estimated_profit  New_col1  Product  col4  \
# Branch
# Banglr       3     3             3                 3         3        3     3
# Delhi        4     4             4                 4         4        4     4
# Hyd          5     5             5                 5         5        5     5
#
#         col5  month  revenue  Branch_code  Cost_value  Branch_cost_value
# Branch
# Banglr     3      3        3            3           3                  0
# Delhi      4      4        4            4           4                  4
# Hyd        5      5        5            5           5                  5

# %%
data1[['Branch','revenue']].groupby('Branch').sum()
# Out:
#           revenue
# Branch
# Banglr  193270260
# Delhi   207270300
# Hyd     322390410

# %%
data1[['Branch','revenue','Estimated_profit']].groupby('Branch').sum()
# Out:
#           revenue  Estimated_profit
# Branch
# Banglr  193270260          39950231
# Delhi   207270300          80200287
# Hyd     322390410          95160364

# %% [markdown]
# ### Group by multiple columns

# %% [markdown]
# #### Series output

# %%
data1.groupby(by=['Branch','Product'])['revenue'].sum()
# Out:
# Branch  Product
# Banglr  EasyCash      61090090
#         SmartSav     132180170
# Delhi   EasyCash      50090090
#         SmartSav      57060070
#         SuperSave    100120140
# Hyd     BusiCard     120140160
#         SmartSav     202250250
# Name: revenue, dtype: int64

# %% [markdown]
# #### Dataframe output

# %%
data1[['Branch','Product', 'revenue']].groupby(by=['Branch','Product']).sum()
# Out:
#                     revenue
# Branch Product
# Banglr EasyCash    61090090
#        SmartSav   132180170
# Delhi  EasyCash    50090090
#        SmartSav    57060070
#        SuperSave  100120140
# Hyd    BusiCard   120140160
#        SmartSav   202250250

# %%
gb1 = data1[['Branch','Product', 'revenue']].groupby(by=['Branch','Product']).sum()

# %%
gb1 = pd.DataFrame(gb1.to_records())
gb1
# Out:
#    index  Branch    Product    revenue
# 0      0  Banglr   EasyCash   61090090
# 1      1  Banglr   SmartSav  132180170
# 2      2   Delhi   EasyCash   50090090
# 3      3   Delhi   SmartSav   57060070
# 4      4   Delhi  SuperSave  100120140
# 5      5     Hyd   BusiCard  120140160
# 6      6     Hyd   SmartSav  202250250

# %% [markdown]
# ### Multi Dataframe - Join, Concate, Merge

# %%
# Out:
#   store  Sales
# 0  vivo  30000
# 1  oppo  25000
# 2    mi  21000

# %%
# Out:
#            0
# 0      vijay
# 1      patil
# 2     pratik
# 3        ram
# 4  [1, 2, 3]

# %%
df4
# Out:
#      name Home_town
# 1  pratik    satara
# 3   akash   nagapur
# 0   vijay  kolhapur
# 2     ram   hingoli

# %%
df5
# Out:
#      name Home_town
# a   vijay  kolhapur
# b  pratik    satara
# c     ram   hingoli
# d   akash   nagapur
# e  Rupesh      None

# %% [markdown]
# ### Row wise comcat

# %%
pd.concat([df4,df5])
# Out:
#      name Home_town
# 1  pratik    satara
# 3   akash   nagapur
# 0   vijay  kolhapur
# 2     ram   hingoli
# a   vijay  kolhapur
# b  pratik    satara
# c     ram   hingoli
# d   akash   nagapur
# e  Rupesh      None

# %% [markdown]
# ### Column wise

# %%
pd.concat([df4,df5], axis = 1)
# Out:
#      name Home_town    name Home_town
# 1  pratik    satara     NaN       NaN
# 3   akash   nagapur     NaN       NaN
# 0   vijay  kolhapur     NaN       NaN
# 2     ram   hingoli     NaN       NaN
# a     NaN       NaN   vijay  kolhapur
# b     NaN       NaN  pratik    satara
# c     NaN       NaN     ram   hingoli
# d     NaN       NaN   akash   nagapur
# e     NaN       NaN  Rupesh      None

# %% [markdown]
# ### Append

# %%
df4.append(df5)
# Out:
# C:\Users\MR.GODHADE\AppData\Local\Temp\ipykernel_10288\1873358701.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4.append(df5)
#      name Home_town
# 1  pratik    satara
# 3   akash   nagapur
# 0   vijay  kolhapur
# 2     ram   hingoli
# a   vijay  kolhapur
# b  pratik    satara
# c     ram   hingoli
# d   akash   nagapur
# e  Rupesh      None

# %% [markdown]
# ### Join

# %%
df4
# Out:
#      name Home_town
# 1  pratik    satara
# 3   akash   nagapur
# 0   vijay  kolhapur
# 2     ram   hingoli

# %%
df5
# Out:
#      name Home_town
# a   vijay  kolhapur
# b  pratik    satara
# c     ram   hingoli
# d   akash   nagapur
# e  Rupesh      None

# %%
df4.join(df5,rsuffix='df5')
# Out:
#      name Home_town namedf5 Home_towndf5
# 1  pratik    satara     NaN          NaN
# 3   akash   nagapur     NaN          NaN
# 0   vijay  kolhapur     NaN          NaN
# 2     ram   hingoli     NaN          NaN

# %%
df4.join(df5,rsuffix='df5',lsuffix='df4')
# Out:
#   namedf4 Home_towndf4 namedf5 Home_towndf5
# 1  pratik       satara     NaN          NaN
# 3   akash      nagapur     NaN          NaN
# 0   vijay     kolhapur     NaN          NaN
# 2     ram      hingoli     NaN          NaN

# %%
df4_i = df4.set_index('name')
df4_i
# Out:
#        Home_town
# name
# pratik    satara
# akash    nagapur
# vijay   kolhapur
# ram      hingoli

# %%
df5_i =df5.set_index('name')
df5_i
# Out:
#        Home_town
# name
# vijay   kolhapur
# pratik    satara
# ram      hingoli
# akash    nagapur
# Rupesh      None

# %% [markdown]
# ### Merge

# %%
df4.merge(df5,on = 'name')
# Out:
#      name Home_town_x Home_town_y
# 0  pratik      satara      satara
# 1   akash     nagapur     nagapur
# 2   vijay    kolhapur    kolhapur
# 3     ram     hingoli     hingoli

# %%
df5.merge(df4,on = 'name')
# Out:
#      name Home_town_x Home_town_y
# 0   vijay    kolhapur    kolhapur
# 1  pratik      satara      satara
# 2     ram     hingoli     hingoli
# 3   akash     nagapur     nagapur

# %%
df5
# Out:
#      name Home_town
# a   vijay  kolhapur
# b  pratik    satara
# c     ram   hingoli
# d   akash   nagapur
# e  Rupesh      None

# %%
df4
# Out:
#      name Home_town
# 1  pratik    satara
# 3   akash   nagapur
# 0   vijay  kolhapur
# 2     ram   hingoli

# %%
pd.merge(df4,df5,how = 'left',on = 'name')
# Out:
#      name Home_town_x Home_town_y
# 0  pratik      satara      satara
# 1   akash     nagapur     nagapur
# 2   vijay    kolhapur    kolhapur
# 3     ram     hingoli     hingoli

# %%
pd.merge(df5,df4,how = 'left',on = 'name')
# Out:
#      name Home_town_x Home_town_y
# 0   vijay    kolhapur    kolhapur
# 1  pratik      satara      satara
# 2     ram     hingoli     hingoli
# 3   akash     nagapur     nagapur
# 4  Rupesh        None         NaN

# %% [markdown]
# ### Column name not common

# %%
pd.merge(df5,df4,how = 'left',left_on = 'name',right_on = 'name')
# Out:
#      name Home_town_x Home_town_y
# 0   vijay    kolhapur    kolhapur
# 1  pratik      satara      satara
# 2     ram     hingoli     hingoli
# 3   akash     nagapur     nagapur
# 4  Rupesh        None         NaN

# %%
df4.index
# Out:
# Int64Index([1, 3, 0, 2], dtype='int64')

# %%
pd.merge(df4,data1,left_on=df4.index,right_on=data1.index,how='inner',right_index= True)
# Out:
#    key_0    name Home_town  Banker Branch      Cost  Costing_rank  \
# 1      1  pratik    satara   99101  Delhi  30060070           2.0
# 3      3   akash   nagapur   99101  Delhi  66660070           9.0
# 0      0   vijay  kolhapur   99101  Delhi  30060070           1.0
# 2      2     ram   hingoli   99101  Delhi  45060070           5.0
#
#    Estimated_profit New_col1    Product              col4      col5  month  \
# 1          20050070     abcd  SuperSave  1504809208404900  1.665334      1
# 3          10050077     abcd   EasyCash  3339008905706300  0.751426      3
# 0          20050070     abcd  SuperSave  1504809208404900  1.665334      1
# 2          30050070     abcd   SmartSav  2571130748404900  1.266311      2
#
#     revenue  Branch_code Cost_value Branch_cost_value
# 1  50060070            1   low_Cost         1low_Cost
# 3  50090090            1  High_Cost        1High_Cost
# 0  50060070            1   low_Cost         1low_Cost
# ...

# %% [markdown]
# ### ML Data Processing

# %%
 1. Duplicate Value removal
 2. Correlation--- duplicate column removal
 3. Missing Data --- remove and Treat
 4. Unique Vlaue---remove when only 1 unique value or unique value = len(data) 
 5.  outliers ---transformation
 6. Feature Engineering ---variety reduction---groupig
 7. lable Encoding --- convert string to numbers
 8. Correlation --delete highly correlated columns
 9. Resampling ---Highlight important factor by copy pasting
 10. Trainig data & testing data split
