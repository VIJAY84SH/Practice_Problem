# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1004-C407
#
#  Directory of C:\Users\vijay\OneDrive\Desktop\Data_Science\Python_Classes
#
# 04/28/2022  07:01 PM    <DIR>          .
# 04/28/2022  07:01 PM    <DIR>          ..
# 04/28/2022  11:24 AM    <DIR>          .ipynb_checkpoints
# 02/16/2022  12:24 PM    <DIR>          __pycache__
# 04/13/2022  03:03 PM            20,039 13th_Feb_mogngodb.ipynb
# 02/02/2022  02:48 PM            22,955 15th_Jan.ipynb
# 02/01/2022  10:16 PM            15,272 15th_jan_Logging.ipynb
# 01/24/2022  01:26 PM            53,959 19Th_Dec_Fun_Practice_Prob.ipynb
# 04/19/2022  02:16 PM            48,584 20th_Feb_SQL_Lite.ipynb
# 02/07/2022  08:38 PM            13,415 22_Jan_22.ipynb
# 02/16/2022  12:22 PM            15,574 23_jan_01.ipynb
# 02/16/2022  12:39 PM             2,640 23_jan_02.ipynb
# 02/23/2022  12:20 PM            17,068 29_jan.ipynb
# 03/20/2022  11:22 AM            69,008 5th_feb_SQL.ipynb
# ...

# %%
pd.read_csv('sample_test.csv')
# Out:
#       name             email_id   address  pincode     sirname
# 0     vijay     vijay@gmail.com      pune      123       patil
# 1   shradha   shradha@gmail.com      pune      123       patil
# 2  vrushali  vrushali@gmail.com  kolhapur      234  shirasekar

# %%
pd.read_csv(r'C:\Users\vijay\Downloads\ohana-api-master\data\sample-csv\locations.csv')
# Out:
#     id  organization_id                                      accessibility  \
# 0    1                1       disabled_parking, ramp, restroom, wheelchair
# 1    2                1                                         wheelchair
# 2    3                1                                                NaN
# 3    4                1                                         wheelchair
# 4    5                1                                         wheelchair
# 5    6                2                       disabled_parking, wheelchair
# 6    7                2       ramp, restroom, disabled_parking, wheelchair
# 7    8                2                                                NaN
# 8    9                3                         ramp, restroom, wheelchair
# 9   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 10  11                3                                               ramp
# ...

# %%
pd.read_csv("taxonomy.csv")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df = pd.read_csv("taxonomy.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1004-C407
#
#  Directory of C:\Users\vijay\OneDrive\Desktop\Data_Science\Python_Classes
#
# 04/28/2022  07:29 PM    <DIR>          .
# 04/28/2022  07:29 PM    <DIR>          ..
# 04/28/2022  11:24 AM    <DIR>          .ipynb_checkpoints
# 02/16/2022  12:24 PM    <DIR>          __pycache__
# 04/13/2022  03:03 PM            20,039 13th_Feb_mogngodb.ipynb
# 02/02/2022  02:48 PM            22,955 15th_Jan.ipynb
# 02/01/2022  10:16 PM            15,272 15th_jan_Logging.ipynb
# 01/24/2022  01:26 PM            53,959 19Th_Dec_Fun_Practice_Prob.ipynb
# 04/19/2022  02:16 PM            48,584 20th_Feb_SQL_Lite.ipynb
# 02/07/2022  08:38 PM            13,415 22_Jan_22.ipynb
# 02/16/2022  12:22 PM            15,574 23_jan_01.ipynb
# 02/16/2022  12:39 PM             2,640 23_jan_02.ipynb
# 02/23/2022  12:20 PM            17,068 29_jan.ipynb
# 03/20/2022  11:22 AM            69,008 5th_feb_SQL.ipynb
# ...

# %%
pd.read_csv("taxonomy.csv",header=None)
# Out:
#                0                             1          2  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         3
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
pd.read_csv("taxonomy.csv",names=['a','b','c','d'])

# we have given own column name
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d
# 0             parent_name
# 1                     NaN
# 2               Emergency
# 3               Emergency
# 4          Emergency Cash
# ..                    ...
# 286  Advocacy & Legal Aid
# 287                 Legal
# ...

# %%
pd.read_csv("taxonomy.csv",names=['a','b','c','d','e'])

# if we give extra column name it will be empty
# Out:
#                a                             b          c  \
# 0    taxonomy_id                          name  parent_id
# 1            101                     Emergency        NaN
# 2         101-01             Disaster Response        101
# 3         101-02                Emergency Cash        101
# 4      101-02-01             Help Pay for Food     101-02
# ..           ...                           ...        ...
# 286    111-01-07              Workplace Rights     111-01
# 287       111-02                     Mediation        111
# 288       111-03                        Notary        111
# 289       111-04                Representation        111
# 290       111-05  Translation & Interpretation        111
#
#                         d   e
# 0             parent_name NaN
# 1                     NaN NaN
# 2               Emergency NaN
# 3               Emergency NaN
# 4          Emergency Cash NaN
# ..                    ...  ..
# 286  Advocacy & Legal Aid NaN
# ...

# %%
pd.read_csv("taxonomy.csv",names=['a','b','c'])

# and if we give less no. of column it will print as you have given
# Out:
#                                         a          b                     c
# taxonomy_id                          name  parent_id           parent_name
# 101                             Emergency        NaN                   NaN
# 101-01                  Disaster Response        101             Emergency
# 101-02                     Emergency Cash        101             Emergency
# 101-02-01               Help Pay for Food     101-02        Emergency Cash
# ...                                   ...        ...                   ...
# 111-01-07                Workplace Rights     111-01  Advocacy & Legal Aid
# 111-02                          Mediation        111                 Legal
# 111-03                             Notary        111                 Legal
# 111-04                     Representation        111                 Legal
# 111-05       Translation & Interpretation        111                 Legal
#
# [291 rows x 3 columns]

# %%
pd.read_csv("sample_test.csv")
# Out:
#       name             email_id   address  pincode     sirname
# 0     vijay     vijay@gmail.com      pune      123       patil
# 1   shradha   shradha@gmail.com      pune      123       patil
# 2  vrushali  vrushali@gmail.com  kolhapur      234  shirasekar

# %%
pd.read_csv("sample_test_01.csv",sep = '@')
# Out:
#                         name   address  pincode     sirname
# vijay    vijay     gmail.com      pune      123       patil
# shradha  shradha   gmail.com      pune      123       patil
# vrushali vrushali  gmail.com  kolhapur      234  shirasekar

# %%
pd.read_csv("sample_test.csv")
# Out:
#               name |email_id|address|pincode|sirname
# 0               vijay|vijay@gmail.com|pune|123|patil
# 1           shradha|shradha@gmail.com|pune|123|patil
# 2  vrushali|vrushali@gmail.com|kolhapur|234|shira...

# %%
pd.read_csv("sample_test.csv",sep = '|')

# separate a data with your own symbol
# Out:
#       name             email_id   address  pincode     sirname
# 0     vijay     vijay@gmail.com      pune      123       patil
# 1   shradha   shradha@gmail.com      pune      123       patil
# 2  vrushali  vrushali@gmail.com  kolhapur      234  shirasekar

# %%
pd.read_csv("sample_test.csv",sep = '|',skiprows=[1 ])

# this skip the rows that you mention
# Out:
#       name             email_id   address  pincode     sirname
# 0   shradha   shradha@gmail.com      pune      123       patil
# 1  vrushali  vrushali@gmail.com  kolhapur      234  shirasekar

# %%
df1 = pd.read_csv("services.csv")

# %%
df1.dtypes

# it shows data type of all column and object is nothing but string here
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
     df1
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df1.head(2)

# this give you a top two sample record as we mention head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df1.tail(3)

# this is showing last 3 records
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
df1.columns

# showing all the columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
a = df1['name']
# this showing perticular column which you want

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
 df1[["name",'location_id','id']]
    
# this is for showing multiple column
# Out:
#                                     name  location_id  id
# 0        Fair Oaks Adult Activity Center            1   1
# 1       Second Career Employment Program            2   2
# 2                 Senior Peer Counseling            3   3
# 3               Family Visitation Center            4   4
# 4      Economic Self-Sufficiency Program            5   5
# 5   Little House Recreational Activities            6   6
# 6       Rosener House Adult Day Services            7   7
# 7         Meals on Wheels - South County            8   8
# 8                       Fair Oaks Branch            9   9
# 9                           Main Library           10  10
# 10                       Schaberg Branch           11  11
# 11                          Project Read           12  12
# 12                 Redwood Shores Branch           13  13
# 13                    Redwood City Corps           14  14
# 14           Adult Rehabilitation Center           15  15
# ...

# %%
 b = df1[["name",'location_id','id']]

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1[["name"]])
# it always return datatye is dataframe bcz we are passing column name as a list
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Operation With Excel file

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1004-C407
#
#  Directory of C:\Users\vijay\OneDrive\Desktop\Data_Science\Python_Classes
#
# 04/29/2022  11:52 AM    <DIR>          .
# 04/29/2022  11:52 AM    <DIR>          ..
# 04/28/2022  11:24 AM    <DIR>          .ipynb_checkpoints
# 02/16/2022  12:24 PM    <DIR>          __pycache__
# 04/13/2022  03:03 PM            20,039 13th_Feb_mogngodb.ipynb
# 02/02/2022  02:48 PM            22,955 15th_Jan.ipynb
# 02/01/2022  10:16 PM            15,272 15th_jan_Logging.ipynb
# 01/24/2022  01:26 PM            53,959 19Th_Dec_Fun_Practice_Prob.ipynb
# 04/19/2022  02:16 PM            48,584 20th_Feb_SQL_Lite.ipynb
# 02/07/2022  08:38 PM            13,415 22_Jan_22.ipynb
# 02/16/2022  12:22 PM            15,574 23_jan_01.ipynb
# 02/16/2022  12:39 PM             2,640 23_jan_02.ipynb
# 02/23/2022  12:20 PM            17,068 29_jan.ipynb
# 03/20/2022  11:22 AM            69,008 5th_feb_SQL.ipynb
# ...

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name= 'Allocations')
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df2 = pd.read_excel("LUSID Excel - Manage Orders.xlsx")

# %%
df2.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df3 = pd.ExcelFile("LUSID Excel - Manage Orders.xlsx")

# %%
df3.sheet_names

# it shows the whatever sheet is available
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# here we reading data without download by using online URL
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
