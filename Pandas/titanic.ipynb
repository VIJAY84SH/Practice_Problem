# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_rich = titanic[titanic.Pclass == 1]

# %%
df_rich
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 11       0    113783  26.5500         C103        S
# 23       0    113788  35.5000           A6        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [216 rows x 12 columns]

# %%
pd.crosstab(df_rich.Sex,df_rich.Survived)
# Out:
# Survived   0   1
# Sex
# female     3  91
# male      77  45

# %% [markdown]
# ### Servived and Gender

# %%
pd.crosstab(titanic.Survived,titanic.Sex)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# #### Total Survived passanger is(233+109)= 342

# %% [markdown]
# #### Total Not-survived passanger is (81+468)= 549

# %%
 (81/(81+468))*100 # around 15% female not survived out of not survived passangers
# Out:
# 14.754098360655737

# %%
(468/(81+468))*100 # around 85% male not survived out of not survived passangers
# Out:
# 85.24590163934425

# %%
(81/(81+233))*100 # around 26% female not survived
# Out:
# 25.796178343949045

# %%
(233/(81+233))*100 # around 74% female survived
# Out:
# 74.20382165605095

# %%
(468/(468+109))*100 # around 81% male not survived
# Out:
# 81.10918544194108

# %%
(109/(468+109))*100 # around 19% male survived
# Out:
# 18.890814558058924

# %% [markdown]
# ______________________________________________________________________________________

# %% [markdown]
# ### Servived and Pclass(Passanger Class)

# %%
pd.crosstab(titanic.Survived,titanic.Pclass,margins=True)
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  372  549
# 1         136   87  119  342
# All       216  184  491  891

# %%
(372/(80+97+372))*100  # around 68% of passangers Death from class3 out of death passangers
# Out:
# 67.75956284153006

# %%
(97/(80+97+372))*100  # around 18% of passangers Death from class2 out of death passangers
# Out:
# 17.66848816029144

# %%
(80/(80+97+372))*100# around 15% of passangers Death from class1 out of death passangers
# Out:
# 14.571948998178508

# %%
(491/891)*100 # More than 50% passangers was traveling from class 3
# Out:
# 55.106621773288445

# %%
(372/(372+119))*100 # near about 76% passengers death from class3
# Out:
# 75.76374745417516

# %%
(97/(97+87))*100 ## near about 53% passangers death from class2
# Out:
# 52.71739130434783

# %%
(80/(80+136))*100    # 37% passengers death from class 1
# Out:
# 37.03703703703704

# %% [markdown]
#  _______________________________________________________________________________________________________________

# %% [markdown]
# ### Survived and Fare

# %%
pd.crosstab(titanic.Fare,titanic.Survived)
# Out:
# Survived   0  1
# Fare
# 0.0000    14  1
# 4.0125     1  0
# 5.0000     1  0
# 6.2375     1  0
# 6.4375     1  0
# ...       .. ..
# 227.5250   1  3
# 247.5208   1  1
# 262.3750   0  2
# 263.0000   2  2
# 512.3292   0  3
#
# [248 rows x 2 columns]

# %% [markdown]
# ### Survived and Sibsp(Number of Siblings/Spouses Aboard)

# %%
pd.crosstab(titanic.Survived,titanic.SibSp)
# Out:
# SibSp       0    1   2   3   4  5  8
# Survived
# 0         398   97  15  12  15  5  7
# 1         210  112  13   4   3  0  0

# %%
398+210  # 608 passangers had 0 siblings
# Out:
# 608

# %%
97+112 # 209 passangers had 1 siblings
# Out:
# 209

# %%
15+13 # 28 passangers had 18 siblings so on
# Out:
# 28

# %%
398/(398+97+15)
# Out:
# 0.7803921568627451

# %% [markdown]
# ### Survived and Embarked

# %% [markdown]
# ##### Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
pd.crosstab(titanic.Survived,titanic.Embarked)
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
(217/(217+427))*100 # aroun 34% passangers  survived which was embarked at Southampton
# Out:
# 33.69565217391305

# %%
(30/(30+47))*100 # around 39% passangers survived which was embarked at Queenstown
# Out:
# 38.961038961038966

# %% [markdown]
# ### Survived and Age

# %%
pd.crosstab(titanic.Age,titanic.Survived)
# Out:
# Survived  0  1
# Age
# 0.42      0  1
# 0.67      0  1
# 0.75      0  2
# 0.83      0  2
# 0.92      0  1
# ...      .. ..
# 70.00     2  0
# 70.50     1  0
# 71.00     2  0
# 74.00     1  0
# 80.00     0  1
#
# [88 rows x 2 columns]

# %%
titanic[titanic['Age'] > 30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 3        0    113803  53.1000  C123        S
# 4        0    373450   8.0500   NaN        S
# 6        0     17463  51.8625   E46        S
# 11       0    113783  26.5500  C103        S
# ..     ...       ...      ...   ...      ...
# 873      0    345765   9.0000   NaN        S
# 879      1     11767  83.1583   C50        C
# 881      0    349257   7.8958   NaN        S
# 885      5    382652  29.1250   NaN        Q
# 890      0    370376   7.7500   NaN        Q
#
# [305 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() #

# %%
titanic[titanic.select_dtypes(include = ['object']).columns] =titanic[titanic.select_dtypes(include = ['object']).columns].apply(le.fit_transform)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0   NaN      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#         Fare  Cabin  Embarked
# 0     7.2500    147         2
# 1    71.2833     81         0
# 2     7.9250    147         2
# 3    53.1000     55         2
# 4     8.0500    147         2
# ..       ...    ...       ...
# 886  13.0000    147         2
# 887  30.0000     30         2
# 888  23.4500    147         2
# 889  30.0000     60         0
# 890   7.7500    147         1
#
# [891 rows x 12 columns]

# %%
titanic.drop(['PassengerId','Cabin','Name','Ticket'],axis = 1,inplace = True)

# %%
titanic.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# dtype: int64

# %%
titanic.Age.fillna(titanic.Age.mean(),inplace = True)

# %%
titanic.isnull().sum()[titanic.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
titanic
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  71.2833         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
# [891 rows x 8 columns]

# %% [markdown]
# ### Group by function

# %%
titanic.groupby('Pclass').Fare.mean().round()
# Out:
# Pclass
# 1    84.0
# 2    21.0
# 3    14.0
# Name: Fare, dtype: float64

# %%
titanic.groupby('Sex').Age.mean().round()
# Out:
# Sex
# 0    28.0
# 1    31.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Sampling

# %%
titanic
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  71.2833         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
# [891 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train_titanic, test_titanic = train_test_split(titanic,test_size = .2)

# %%
titanic.shape,train_titanic.shape,test_titanic.shape
# Out:
# ((891, 8), (712, 8), (179, 8))

# %%
#712+179,
# Out:
# 891

# %%
train_titanic.head()
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 400         1       3    1  39.0      0      0   7.9250         2
# 148         0       2    1  36.5      0      2  26.0000         2
# 808         0       2    1  39.0      0      0  13.0000         2
# 688         0       3    1  18.0      0      0   7.7958         2
# 559         1       3    0  36.0      1      0  17.4000         2

# %%
train_titanic_x = train_titanic.iloc[ : , 1:]
train_titanic_y = train_titanic.iloc[ : ,0]

# %%
test_titanic_x = test_titanic.iloc[ : , 1:]
test_titanic_y =test_titanic.iloc[ : ,0]

# %%
train_titanic_y.head()
# Out:
# 400    1
# 148    0
# 808    0
# 688    0
# 559    1
# Name: Survived, dtype: int64

# %%
test_titanic_x.head(2)
# Out:
#      Pclass  Sex        Age  SibSp  Parch    Fare  Embarked
# 57        3    1  28.500000      0      0  7.2292         0
# 697       3    0  29.699118      0      0  7.7333         1

# %% [markdown]
# ### Functions

# %%
df2  = pd.DataFrame({"Jan": ( 100 , 121, 124)  , "Feb":( 132, 140, 153)  , "Mar": ( 200 , 201, 300)})

# %%
df2
# Out:
#    Jan  Feb  Mar
# 0  100  132  200
# 1  121  140  201
# 2  124  153  300

# %%
df3 = pd.DataFrame({"Jan": ( 100 , 121, 124)  , "Feb":( 132, 140, 153)  , "Mar": ( 200 , 201, 300)})

# %%
df3
# Out:
#    Jan  Feb  Mar
# 0  100  132  200
# 1  121  140  201
# 2  124  153  300

# %%
df3_a= df3.add_suffix("_Month")

# %%
df3_a
# Out:
#    Jan_Month  Feb_Month  Mar_Month
# 0        100        132        200
# 1        121        140        201
# 2        124        153        300

# %%
df4_b= df3.add_prefix("Month_")

# %%
df4_b
# Out:
#    Month_Jan  Month_Feb  Month_Mar
# 0        100        132        200
# 1        121        140        201
# 2        124        153        300

# %%
cr = pd.read_csv(r'C:\Users\MR.GODHADE\Desktop\Untitled Folder\CreditRisk.csv')

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
cr.sort_values('ApplicantIncome', ascending= True).head()
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 639  LP001153    Male      No         0.0      Graduate            No
# 730  LP001607  Female      No         0.0  Not Graduate            No
# 216  LP001722    Male     Yes         0.0      Graduate            No
# 468  LP002502  Female     Yes         2.0  Not Graduate           NaN
# 600  LP002949  Female      No         4.0      Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 639                0            24000.0       148.0             360.0
# 730                0             1760.0       180.0             360.0
# 216              150             1800.0       135.0             360.0
# 468              210             2917.0        98.0             360.0
# 600              416            41667.0       350.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 639             0.0         Rural           N
# 730             1.0     Semiurban           N
# 216             1.0         Rural           N
# 468             1.0     Semiurban           Y
# 600             NaN         Urban           N
